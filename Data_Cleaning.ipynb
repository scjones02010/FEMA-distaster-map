# %% [markdown]
# Imports needed for cleaning

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# dictionary to remap categories

# %%
FEMA_dict={
'safestores,safetyequipment,securitysystems,security':'(1) safety and security',
'convenience,delicatessen,ethicgrocery,foodtrucks,intlgrocery,meatsseafoodmarkets,waterstores,watersuppliers,waterheaterinstallrepair,waterpurification,waterdelivery,homelessshelters,hotels,hotelstravel,university_housing,housingcooperatives':'(2) Food, water, sheltering',
'hospitalists,emergencyrooms,medicalsupplies,medicalspa,medcenters,medicalfoot,medicaltransportation,blooddonation,conciergemedicine,diagnosticservices,dialysisclinics,anesthesiologists,cardiology,earnosethroat,emergencymedicine,endocrinologists,familydr,homeopathic,immunodermatologists,internalmed,neurologist,painmanagement,pediatricians,podiatrists,preventivemedicine,radiologists,rhematologists,spinesurgeons,surgeons,urologists,homehealthcare':'(3) Health and medical',
'outdoorpowerequipmentservices,utilities,servicestations,fueldocks,electricians,autoelectric':'(4) Energy (power, fuel)',
'telecommunications,datarecovery,mobilephones,mobilephonerepair,internetbooth,isps,internetcafe':'(5) Communications',
'medicaltransportation,transport':'(6) Transportation',
'biohazardcleanup,hazardouswastedisposal':'(7) Hazardous Waste',
'policedepartments,emergencymedicine,fireprotection,firedepartments':'Police, Medical and Fire Assistance'}

# %% [markdown]
# Importing Dataframes for cleaning and merging

# %%
adel_energy=pd.read_csv('./webscrapes/energy_Adel_df.csv',index_col='Unnamed: 0')
adel_food=pd.read_csv('./webscrapes/food_Adel_df.csv',index_col='Unnamed: 0')
adel_haz=pd.read_csv('./webscrapes/haz_Adel_df.csv',index_col='Unnamed: 0')
adel_health=pd.read_csv('./webscrapes/health_Adel_df.csv',index_col='Unnamed: 0')
adel_police=pd.read_csv('./webscrapes/police_Adel_df.csv',index_col='Unnamed: 0')
adel_safety=pd.read_csv('./webscrapes/safety_Adel_df.csv',index_col='Unnamed: 0')
adel_telecom=pd.read_csv('./webscrapes/telecom_Adel_df.csv',index_col='Unnamed: 0')
adel_transit=pd.read_csv('./webscrapes/trans_Adel_df.csv',index_col='Unnamed: 0')
adel=pd.concat([adel_energy,adel_food,adel_haz,adel_health,adel_police,adel_safety,adel_telecom,adel_transit])
adel.head()
# Out:
#                   name                                      address  \
# 0  Magnolia Plantation  ['35 Omega Eldorado Rd', 'Lenox, GA 31637']
# 1       Stuckeys Citgo          ['1003 W 4th St', 'Adel, GA 31620']
# 2     Citgo Truck Stop             ['Georgia 37', 'Adel, GA 31620']
# 3       BP Gas Station          ['1200 W 4th St', 'Adel, GA 31620']
# 4   Love's Travel Stop   ['178 Southwell Blvd', 'Tifton, GA 31794']
#
#      phone_number  location_latitude  location_longitude  is_closed    city  \
# 0  (229) 382-3372          31.356990          -83.487994      False   Lenox
# 1  (229) 896-4180          31.134262          -83.436631      False    Adel
# 2             NaN          31.138632          -83.444746      False    Adel
# 3  (229) 896-7575          31.137121          -83.440283      False    Adel
# 4  (229) 382-9118          31.415728          -83.503092      False  Tifton
#
#    zip_code            category  \
# 0   31637.0        Candy Stores
# ...

# %%
albany_energy=pd.read_csv('./webscrapes/energy_Albany_df.csv',index_col='Unnamed: 0')
albany_food=pd.read_csv('./webscrapes/food_Albany_df.csv',index_col='Unnamed: 0')
albany_haz=pd.read_csv('./webscrapes/haz_Albany_df.csv',index_col='Unnamed: 0')
albany_health=pd.read_csv('./webscrapes/health_Albany_df.csv',index_col='Unnamed: 0')
albany_police=pd.read_csv('./webscrapes/police_Albany_df.csv',index_col='Unnamed: 0')
albany_safety=pd.read_csv('./webscrapes/safety_Albany_df.csv',index_col='Unnamed: 0')
albany_telecom=pd.read_csv('./webscrapes/telecom_Albany_df.csv',index_col='Unnamed: 0')
albany_transit=pd.read_csv('./webscrapes/trans_Albany_df.csv',index_col='Unnamed: 0')
albany=pd.concat([albany_energy,albany_food,albany_haz,albany_health,albany_police,albany_safety,albany_telecom,albany_transit])
albany.head()
# Out:
#                                         name  \
# 0                                     Enmark
# 1  B & B Electrical Contractors & Associates
# 2             Preferred Home Repair Handyman
# 3                              Homerun Foods
# 4                        Pilot Travel Center
#
#                                     address    phone_number  \
# 0    ['2424 Clark Ave', 'Albany, GA 31705']  (229) 483-0137
# 1  ['1008 W Broad Ave', 'Albany, GA 31701']  (229) 435-0287
# 2  ['2823 Meredyth Dr', 'Albany, GA 31707']  (229) 317-2271
# 3    ['2722 Dawson Rd', 'Albany, GA 31707']  (229) 435-0443
# 4    ['310 Cordele Rd', 'Albany, GA 31705']  (229) 878-1355
#
#    location_latitude  location_longitude  is_closed    city  zip_code  \
# 0          31.579650          -84.091130      False  Albany     31705
# 1          31.576410          -84.174530      False  Albany     31701
# 2          31.611086          -84.221721      False  Albany     31707
# ...

# %%
alpharetta_energy=pd.read_csv('./webscrapes/energy_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_food=pd.read_csv('./webscrapes/food_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_haz=pd.read_csv('./webscrapes/haz_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_health=pd.read_csv('./webscrapes/health_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_police=pd.read_csv('./webscrapes/police_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_safety=pd.read_csv('./webscrapes/safty_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_telecom=pd.read_csv('./webscrapes/telecom_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta_transit=pd.read_csv('./webscrapes/trans_Alpharetta_df.csv',index_col='Unnamed: 0')
alpharetta=pd.concat([alpharetta_energy,alpharetta_food,alpharetta_haz,alpharetta_health,alpharetta_police,alpharetta_safety,alpharetta_telecom,alpharetta_transit])
alpharetta.head()
# Out:
#                                                 name  \
# 0  TE Certified Electrical, Plumbing, Heating & C...
# 1                                           QuikTrip
# 2                                          Quik Trip
# 3                                           Speedway
# 4                                   Cameron Electric
#
#                                              address    phone_number  \
# 0       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 1  ['11700 Haynes Bridge Rd', 'Alpharetta, GA 300...  (770) 752-9890
# 2   ['3190 Old Milton Pkwy', 'Alpharetta, GA 30009']  (770) 753-2671
# 3     ['910 Mcfarland Pkwy', 'Alpharetta, GA 30004']  (770) 667-3732
# 4        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
#
#    location_latitude  location_longitude  is_closed        city  zip_code  \
# 0          34.018702          -84.328872      False     Roswell     30075
# 1          34.066870          -84.294070      False  Alpharetta     30009
# ...

# %%
athens_energy=pd.read_csv('./webscrapes/energy_Athens_df.csv',index_col='Unnamed: 0')
athens_food=pd.read_csv('./webscrapes/food_Athens_df.csv',index_col='Unnamed: 0')
athens_haz=pd.read_csv('./webscrapes/haz_Athens_df.csv',index_col='Unnamed: 0')
athens_health=pd.read_csv('./webscrapes/health_Athens_df.csv',index_col='Unnamed: 0')
athens_police=pd.read_csv('./webscrapes/police_Athens_df.csv',index_col='Unnamed: 0')
athens_safety=pd.read_csv('./webscrapes/safety_Athens_df.csv',index_col='Unnamed: 0')
athens_telecom=pd.read_csv('./webscrapes/telecom_Athens_df.csv',index_col='Unnamed: 0')
athens_transit=pd.read_csv('./webscrapes/trans_Athens_df.csv',index_col='Unnamed: 0')
athens=pd.concat([athens_energy,athens_food,athens_haz,athens_health,athens_police,athens_safety,athens_telecom,athens_transit])
athens.head()
# Out:
#                            name  \
# 0                      QuikTrip
# 1               Bittle Electric
# 2                       Jimbo's
# 3  Alternative Energy Southeast
# 4                      RaceTrac
#
#                                              address    phone_number  \
# 0      ['1240 Oconee Connector', 'Athens, GA 30606']  (706) 546-5733
# 1            ['110 Chadds Walk', 'Athens, GA 30606']  (706) 549-9058
# 2              ['697 Baxter St', 'Athens, GA 30605']  (706) 548-1521
# 3  ['160 Collins Industrial Blvd', 'Athens, GA 30...  (770) 691-0966
# 4           ['2625 Atlanta Hwy', 'Athens, GA 30606']             NaN
#
#    location_latitude  location_longitude  is_closed    city  zip_code  \
# 0          33.907134          -83.463975      False  Athens     30606
# 1          33.969662          -83.439728      False  Athens     30606
# 2          33.949650          -83.384644      False  Athens     30605
# ...

# %%
altanta_energy=pd.read_csv('./webscrapes/energy_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_food=pd.read_csv('./webscrapes/food_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_haz=pd.read_csv('./webscrapes/haz_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_health=pd.read_csv('./webscrapes/health_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_police=pd.read_csv('./webscrapes/police_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_safety=pd.read_csv('./webscrapes/safety_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_telecom=pd.read_csv('./webscrapes/telecom_Atlanta_df.csv',index_col='Unnamed: 0')
altanta_transit=pd.read_csv('./webscrapes/trans_Atlanta_df.csv',index_col='Unnamed: 0')
atlanta=pd.concat([altanta_energy,altanta_food,altanta_haz,altanta_health,altanta_police,altanta_safety,altanta_telecom,altanta_transit])
atlanta.head()
# Out:
#                   name                                            address  \
# 0    Handy Electrician  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...
# 1  JEFF ELECTRIC CORP.  ['1270 Caroline St NE', 'Ste D104', 'Atlanta, ...
# 2     Beazley Electric      ['1165 Lullwater Rd NE', 'Atlanta, GA 30307']
# 3     Cameron Electric        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']
# 4             QuikTrip        ['1836 Briarcliff Rd', 'Atlanta, GA 30329']
#
#      phone_number  location_latitude  location_longitude  is_closed     city  \
# 0  (678) 873-5674          33.745860          -84.358690      False  Atlanta
# 1  (404) 775-4891          33.758584          -84.347345      False  Atlanta
# 2  (404) 281-4896          33.786170          -84.328830      False  Atlanta
# 3  (404) 891-6448          33.928235          -84.307313      False  Atlanta
# 4  (404) 325-1931          33.806908          -84.336220      False  Atlanta
#
# ...

# %%
americus_energy=pd.read_csv('./webscrapes/energy_Americus_df.csv',index_col='Unnamed: 0')
americus_food=pd.read_csv('./webscrapes/food_Americus_df.csv',index_col='Unnamed: 0')
americus_health=pd.read_csv('./webscrapes/health_Americus_df.csv',index_col='Unnamed: 0')
americus_police=pd.read_csv('./webscrapes/police_Americus_df.csv',index_col='Unnamed: 0')
americus_safety=pd.read_csv('./webscrapes/safety_Americus_df.csv',index_col='Unnamed: 0')
americus_telecom=pd.read_csv('./webscrapes/telecom_Americus_df.csv',index_col='Unnamed: 0')
americus_transit=pd.read_csv('./webscrapes/trans_Americus_df.csv',index_col='Unnamed: 0')
americus=pd.concat([americus_energy,americus_food,americus_health,americus_police,americus_safety,americus_telecom,americus_transit])
americus.head()
# Out:
#                                 name  \
# 0  Perry Brothers Oil & Tire Company
# 1                      Wayne's World
# 2                  Americus Gas N Go
# 3                   Wayne's Electric
# 4     Preferred Home Repair Handyman
#
#                                        address    phone_number  \
# 0   ['125 US Hwy 280 W', 'Americus, GA 31709']  (229) 924-0306
# 1  ['1043 E Forsyth St', 'Americus, GA 31709']  (229) 924-0879
# 2    ['202 US Hwy 19 S', 'Americus, GA 31719']  (229) 931-8940
# 3  ['231 A US Hwy 19 S', 'Americus, GA 31719']  (229) 924-3421
# 4     ['2823 Meredyth Dr', 'Albany, GA 31707']  (229) 317-2271
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          32.063936          -84.255309      False  Americus     31709
# 1          32.073044          -84.218575      False  Americus     31709
# 2          32.063958          -84.253267      False  Americus     31719
# ...

# %%
auburn_energy=pd.read_csv('./webscrapes/energy_Auburn_df.csv',index_col='Unnamed: 0')
auburn_food=pd.read_csv('./webscrapes/food_Auburn_df.csv',index_col='Unnamed: 0')
auburn_haz=pd.read_csv('./webscrapes/haz_Auburn_df.csv',index_col='Unnamed: 0')
auburn_health=pd.read_csv('./webscrapes/health_Auburn_df.csv',index_col='Unnamed: 0')
auburn_police=pd.read_csv('./webscrapes/police_Auburn_df.csv',index_col='Unnamed: 0')
auburn_safety=pd.read_csv('./webscrapes/safety_Auburn_df.csv',index_col='Unnamed: 0')
auburn_telecom=pd.read_csv('./webscrapes/telecom_Auburn_df.csv',index_col='Unnamed: 0')
auburn_transit=pd.read_csv('./webscrapes/trans_Auburn_df.csv',index_col='Unnamed: 0')
auburn=pd.concat([auburn_energy,auburn_food,auburn_haz,auburn_health,auburn_police,auburn_safety,auburn_telecom,auburn_transit])
auburn.head()
# Out:
#                            name  \
# 0             Big Frog Electric
# 1               Electrical Pros
# 2  Dependable Electric Services
# 3                      QuikTrip
# 4                      QuikTrip
#
#                                           address    phone_number  \
# 0            ['36 E Main St', 'Buford, GA 30518']  (770) 559-9009
# 1    ['1107 Ewing Chapel Rd', 'Dacula, GA 30019']  (770) 822-2150
# 2  ['1798 N Round Rd', 'Lawrenceville, GA 30045']  (404) 789-4811
# 3   ['2460 Hamilton Mill Rd', 'Dacula, GA 30019']  (770) 932-1914
# 4         ['1750 Winder Hwy', 'Dacula, GA 30019']  (678) 377-7808
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          34.120510          -84.005698      False         Buford   30518.0
# 1          33.958432          -83.894197      False         Dacula   30019.0
# 2          33.916323          -83.929285      False  Lawrenceville   30045.0
# ...

# %%
augusta_energy=pd.read_csv('./webscrapes/energy_Augusta_df.csv',index_col='Unnamed: 0')
augusta_food=pd.read_csv('./webscrapes/food_Augusta_df.csv',index_col='Unnamed: 0')
augusta_haz=pd.read_csv('./webscrapes/haz_Augusta_df.csv',index_col='Unnamed: 0')
augusta_health=pd.read_csv('./webscrapes/health_Augusta_df.csv',index_col='Unnamed: 0')
augusta_police=pd.read_csv('./webscrapes/police_Augusta_df.csv',index_col='Unnamed: 0')
augusta_safety=pd.read_csv('./webscrapes/safety_Augusta_df.csv',index_col='Unnamed: 0')
augusta_telecom=pd.read_csv('./webscrapes/telecom_Augusta_df.csv',index_col='Unnamed: 0')
augusta_transit=pd.read_csv('./webscrapes/trans_Augusta_df.csv',index_col='Unnamed: 0')
augusta=pd.concat([augusta_energy,augusta_food,augusta_haz,augusta_health,augusta_police,augusta_safety,augusta_telecom,augusta_transit])
augusta.head()
# Out:
#                       name                                       address  \
# 0       Minyard's Electric          ['254 Rose St', 'Augusta, GA 30907']
# 1  Mr. Electric of Augusta                         ['Augusta, GA 30906']
# 2                   Kroger  ['3435 Wrightsboro Rd', 'Augusta, GA 30909']
# 3     1st Call Maintenance                         ['Augusta, GA 30909']
# 4    Georgia Power Company          ['301 15th St', 'Augusta, GA 30901']
#
#      phone_number  location_latitude  location_longitude  is_closed     city  \
# 0  (706) 863-3242          33.506830          -82.087570      False  Augusta
# 1  (706) 619-2525          33.389598          -81.980793      False  Augusta
# 2  (706) 733-6811          33.468590          -82.080688      False  Augusta
# 3  (706) 836-2665          33.468840          -82.062000      False  Augusta
# 4  (706) 236-1405          33.479890          -81.984630      False  Augusta
#
#    zip_code               category  \
# ...

# %%
baxley_energy=pd.read_csv("./webscrapes/energy_Baxley_df.csv",index_col='Unnamed: 0')
baxley_food=pd.read_csv('./webscrapes/food_Baxley_df.csv',index_col='Unnamed: 0')
baxley_haz=pd.read_csv('./webscrapes/haz_Baxley_df.csv',index_col='Unnamed: 0')
baxley_health=pd.read_csv('./webscrapes/health_Baxley_df.csv',index_col='Unnamed: 0')
baxley_police=pd.read_csv('./webscrapes/police_Baxley_df.csv',index_col='Unnamed: 0')
baxley_safety=pd.read_csv('./webscrapes/safety_Baxley_df.csv',index_col='Unnamed: 0')
baxley_telecom=pd.read_csv('./webscrapes/telecom_Baxley_df.csv',index_col='Unnamed: 0')
baxley_transit=pd.read_csv('./webscrapes/trans_Baxley_df.csv',index_col='Unnamed: 0')
baxley=pd.concat([baxley_energy,baxley_food,baxley_haz,baxley_health,baxley_police,baxley_safety,baxley_telecom,baxley_transit])
baxley.head()
# Out:
#                       name                                            address  \
# 0         Parkers Surrency  ['9674 Golden Isle Hwy E', 'Hazlehurst, GA 315...
# 1          Joe's Quik Stop                 ['495 Bay St', 'Baxley, GA 31513']
# 2              Flash Foods     ['100 East Jarman St', 'Hazlehurst, GA 31539']
# 3  Big Al's Country Market         ['1210 Highway 29', 'Tarrytown, GA 30470']
# 4                 Johns #2                ['4384 GA-15', 'Vidalia, GA 30474']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 367-1006          31.725221          -82.197438      False
# 1  (912) 367-9476          31.777855          -82.357654      False
# 2  (912) 375-5285          31.865370          -82.589150      False
# 3  (912) 538-8900          32.203186          -82.413838      False
# 4             NaN          32.128612          -82.396990      False
#
#          city  zip_code            category  \
# ...

# %%
brookhaven_energy=pd.read_csv("./webscrapes/energy_Brookhaven_df.csv",index_col='Unnamed: 0')
brookhaven_food=pd.read_csv('./webscrapes/food_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven_haz=pd.read_csv('./webscrapes/haz_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven_health=pd.read_csv('./webscrapes/health_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven_police=pd.read_csv('./webscrapes/police_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven_safety=pd.read_csv('./webscrapes/safety_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven_telecom=pd.read_csv('./webscrapes/telecom_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven_transit=pd.read_csv('./webscrapes/trans_Brookhaven_df.csv',index_col='Unnamed: 0')
brookhaven=pd.concat([brookhaven_energy,brookhaven_food,brookhaven_haz,brookhaven_health,brookhaven_police,brookhaven_safety,brookhaven_telecom,brookhaven_transit])
brookhaven.head()
# Out:
#                                                 name  \
# 0                                   Cameron Electric
# 1                                             Costco
# 2  TE Certified Electrical, Plumbing, Heating & C...
# 3                                   Mccurley's Shell
# 4                                   Beazley Electric
#
#                                              address    phone_number  \
# 0        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 1  ['6350 Peachtree Dunwoody Rd NE', 'Atlanta, GA...  (770) 352-8672
# 2       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 3  ['2080 N Druid Hills Rd NE', 'Brookhaven, GA 3...  (404) 636-2950
# 4      ['1165 Lullwater Rd NE', 'Atlanta, GA 30307']  (404) 281-4896
#
#    location_latitude  location_longitude  is_closed        city  zip_code  \
# 0          33.928235          -84.307313      False     Atlanta   30338.0
# 1          33.928332          -84.354318      False     Atlanta   30328.0
# ...

# %%
carrollton_energy=pd.read_csv('./webscrapes/energy_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_food=pd.read_csv('./webscrapes/food_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_haz=pd.read_csv('./webscrapes/haz_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_health=pd.read_csv('./webscrapes/health_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_police=pd.read_csv('./webscrapes/police_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_safety=pd.read_csv('./webscrapes/safety_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_telecom=pd.read_csv('./webscrapes/telecom_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton_transit=pd.read_csv('./webscrapes/trans_Carrollton_df.csv',index_col='Unnamed: 0')
carrollton=pd.concat([carrollton_energy,carrollton_food,carrollton_haz,carrollton_health,carrollton_police,carrollton_safety,carrollton_telecom,carrollton_transit])
carrollton.head()
# Out:
#                         name  \
# 0  Harry T's Car Wash & Lube
# 1                      CITGO
# 2                 Murphy USA
# 3               MC6 Electric
# 4                    Chevron
#
#                                              address    phone_number  \
# 0       ['730 Bankhead Hwy', 'Carrollton, GA 30117']  (770) 836-1515
# 1        ['1101 Alabama St', 'Carrollton, GA 30117']  (770) 832-0664
# 2      ['1725 S Highway 27', 'Carrollton, GA 30117']  (770) 838-4440
# 3  ['1002 Highway 16 W', 'Ste A', 'Newnan, GA 302...  (678) 552-9399
# 4          ['1201 Maple St', 'Carrollton, GA 30117']  (770) 214-8500
#
#    location_latitude  location_longitude  is_closed        city  zip_code  \
# 0          33.589080          -85.052290      False  Carrollton   30117.0
# 1          33.588497          -85.099580      False  Carrollton   30117.0
# 2          33.543509          -85.074034      False  Carrollton   30117.0
# ...

# %%
cedartown_energy=pd.read_csv('./webscrapes/energy_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_food=pd.read_csv('./webscrapes/food_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_haz=pd.read_csv('./webscrapes/haz_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_health=pd.read_csv('./webscrapes/health_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_police=pd.read_csv('./webscrapes/police_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_safety=pd.read_csv('./webscrapes/safety_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_telecom=pd.read_csv('./webscrapes/telecom_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown_transit=pd.read_csv('./webscrapes/trans_Cedartown_df.csv',index_col='Unnamed: 0')
cedartown=pd.concat([cedartown_energy,cedartown_food,cedartown_haz,cedartown_health,cedartown_police,cedartown_safety,cedartown_telecom,cedartown_transit])
cedartown.head()
# Out:
#                                               name  \
# 0                                  Tanner Electric
# 1                                         Circle K
# 2                                               BP
# 3                                          Raceway
# 4  Casteel Heating, Cooling, Plumbing & Electrical
#
#                                            address    phone_number  \
# 0          ['162 Terhune Rd SE', 'Rome, GA 30161']  (706) 290-1134
# 1      ['3070 Cedartown Hwy SW', 'Rome, GA 30161']  (706) 290-9495
# 2           ['104 Gtm Pkwy', 'Rockmart, GA 30153']  (770) 684-8770
# 3  ['1951 Nathan Dean Pkwy', 'Rockmart, GA 30153']  (770) 684-2848
# 4         ['2218 Canton Rd', 'Marietta, GA 30066']  (678) 723-6272
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          34.182860          -85.072620      False      Rome   30161.0
# 1          34.174974          -85.207962      False      Rome   30161.0
# ...

# %%
clarkesville_energy=pd.read_csv('./webscrapes/energy_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_food=pd.read_csv('./webscrapes/food_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_haz=pd.read_csv('./webscrapes/haz_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_health=pd.read_csv('./webscrapes/health_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_police=pd.read_csv('./webscrapes/police_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_safety=pd.read_csv('./webscrapes/safety_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_telecom=pd.read_csv('./webscrapes/telecom_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville_transit=pd.read_csv('./webscrapes/trans_Clarkesville_df.csv',index_col='Unnamed: 0')
clarkesville=pd.concat([clarkesville_energy,clarkesville_food,clarkesville_haz,clarkesville_health,clarkesville_police,clarkesville_safety,clarkesville_telecom,clarkesville_transit])
clarkesville.head()
# Out:
#                    name                                            address  \
# 0        Ready Electric                            ['Cleveland, GA 30528']
# 1                M Mart     ['1384 Tom Born Rd', 'Clarkesville, GA 30523']
# 2                 Citgo  ['305 Panther Brook Ln', 'Clarkesville, GA 305...
# 3       Midway Electric    ['4906 Cannon Bridge Rd', 'Demorest, GA 30535']
# 4  Sautee Shell Express   ['5028 Helen Hwy', 'Sautee Nacoochee, GA 30571']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (706) 969-9964          34.644857          -83.457237      False
# 1  (706) 754-1556          34.675954          -83.428653      False
# 2  (706) 839-1870          34.678455          -83.424272      False
# 3  (706) 754-6218          34.578430          -83.608730      False
# 4  (706) 219-0052          34.662870          -83.719764      False
#
#                city  zip_code            category  \
# 0         Cleveland   30528.0        Electricians
# ...

# %%
cochran_energy=pd.read_csv('./webscrapes/energy_Cochran_df.csv',index_col='Unnamed: 0')
cochran_food=pd.read_csv('./webscrapes/food_Cochran_df.csv',index_col='Unnamed: 0')
cochran_health=pd.read_csv('./webscrapes/health_Cochran_df.csv',index_col='Unnamed: 0')
cochran_police=pd.read_csv('./webscrapes/police_Cochran_df.csv',index_col='Unnamed: 0')
cochran_safety=pd.read_csv('./webscrapes/safety_Cochran_df.csv',index_col='Unnamed: 0')
cochran_telecom=pd.read_csv('./webscrapes/telecom_Cochran_df.csv',index_col='Unnamed: 0')
cochran_transit=pd.read_csv('./webscrapes/trans_Cochran_df.csv',index_col='Unnamed: 0')
cochran=pd.concat([cochran_energy,cochran_food,cochran_health,cochran_police,cochran_safety,cochran_telecom,cochran_transit])
cochran.head()
# Out:
#                        name  \
# 0        Love's Travel Stop
# 1               Flash Foods
# 2        Pinehurst Gas N Go
# 3  Jarrell Electric Company
# 4     LOLO Cigarette Outlet
#
#                                              address    phone_number  \
# 0               ['3009 Hwy 257', 'Dublin, GA 31021']  (478) 296-1368
# 1                ['107 Iffie Rd', 'Perry, GA 31069']  (478) 988-3303
# 2  ['824 Pinehurst Hawkinsville Rd', 'Pinehurst, ...  (229) 645-3479
# 3     ['1319 Coley Station Rd', 'Cochran, GA 31014']  (478) 934-7707
# 4                        ['Warner Robins, GA 31005']             NaN
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          32.496140          -82.981690      False         Dublin   31021.0
# 1          32.446240          -83.753230      False          Perry   31069.0
# 2          32.190476          -83.749376      False      Pinehurst   31070.0
# ...

# %%
college_park_energy=pd.read_csv('./webscrapes/energy_College_Park_df.csv',index_col='Unnamed: 0')
college_park_food=pd.read_csv('./webscrapes/food_College_Park_df.csv',index_col='Unnamed: 0')
college_park_haz=pd.read_csv('./webscrapes/haz_College_Park_df.csv',index_col='Unnamed: 0')
college_park_health=pd.read_csv('./webscrapes/health_College_Park_df.csv',index_col='Unnamed: 0')
college_park_police=pd.read_csv('./webscrapes/police_College_Park_df.csv',index_col='Unnamed: 0')
college_park_safety=pd.read_csv('./webscrapes/safety_College_Park_df.csv',index_col='Unnamed: 0')
college_park_telecom=pd.read_csv('./webscrapes/telecom_College_Park_df.csv',index_col='Unnamed: 0')
college_park_transit=pd.read_csv('./webscrapes/trans_College_Park_df.csv',index_col='Unnamed: 0')
college_park=pd.concat([college_park_energy,college_park_food,college_park_haz,college_park_health,college_park_police,college_park_safety,college_park_telecom,college_park_transit])
college_park.head()
# Out:
#                   name                                            address  \
# 0    Handy Electrician  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...
# 1  JEFF ELECTRIC CORP.  ['1270 Caroline St NE', 'Ste D104', 'Atlanta, ...
# 2             QuikTrip    ['5390 Riverdale Rd', 'College Park, GA 30349']
# 3       Estes Services       ['3981 Tradeport Blvd', 'Atlanta, GA 30354']
# 4     Cameron Electric        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (678) 873-5674          33.745860          -84.358690      False
# 1  (404) 775-4891          33.758584          -84.347345      False
# 2  (770) 994-0186          33.608574          -84.435613      False
# 3  (404) 362-6965          33.646239          -84.395519      False
# 4  (404) 891-6448          33.928235          -84.307313      False
#
#            city  zip_code                         category  \
# ...

# %%
columbus_energy=pd.read_csv('./webscrapes/energy_Columbus_df.csv',index_col='Unnamed: 0')
columbus_food=pd.read_csv('./webscrapes/food_Columbus_df.csv',index_col='Unnamed: 0')
columbus_haz=pd.read_csv('./webscrapes/haz_Columbus_df.csv',index_col='Unnamed: 0')
columbus_health=pd.read_csv('./webscrapes/health_Columbus_df.csv',index_col='Unnamed: 0')
columbus_police=pd.read_csv('./webscrapes/police_Columbus_df.csv',index_col='Unnamed: 0')
columbus_safety=pd.read_csv('./webscrapes/safety_Columbus_df.csv',index_col='Unnamed: 0')
columbus_telecom=pd.read_csv('./webscrapes/telecom_Columbus_df.csv',index_col='Unnamed: 0')
columbus_transit=pd.read_csv('./webscrapes/trans_Columbus_df.csv',index_col='Unnamed: 0')
columbus=pd.concat([columbus_energy,columbus_food,columbus_haz,columbus_health,columbus_police,columbus_safety,columbus_telecom,columbus_transit])
columbus.head()
# Out:
#                            name  \
# 0  Mr. Electric of Columbus, GA
# 1               Shell Food Mart
# 2                      Circle K
# 3     University Avenue Chevron
# 4       Jordan Electric Company
#
#                                           address    phone_number  \
# 0                          ['Columbus, GA 31907']  (706) 785-0111
# 1  ['5700 Warm Springs Rd', 'Columbus, GA 31909']  (706) 563-7272
# 2    ['7330 Veterans Pkwy', 'Columbus, GA 31909']  (706) 243-3171
# 3         ['3711 Macon Rd', 'Columbus, GA 31907']  (706) 565-8050
# 4  ['4923 Warm Springs Rd', 'Columbus, GA 31909']  (706) 563-1909
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          32.508602          -84.915342      False  Columbus     31907
# 1          32.543223          -84.893936      False  Columbus     31909
# 2          32.553460          -84.947020      False  Columbus     31909
# 3          32.489601          -84.931625      False  Columbus     31907
# ...

# %%
commerce_energy=pd.read_csv('./webscrapes/energy_Commerce_df.csv',index_col='Unnamed: 0')
commerce_food=pd.read_csv('./webscrapes/food_Commerce_df.csv',index_col='Unnamed: 0')
commerce_haz=pd.read_csv('./webscrapes/haz_Commerce_df.csv',index_col='Unnamed: 0')
commerce_health=pd.read_csv('./webscrapes/health_Commerce_df.csv',index_col='Unnamed: 0')
commerce_police=pd.read_csv('./webscrapes/police_Commerce_df.csv',index_col='Unnamed: 0')
commerce_safety=pd.read_csv('./webscrapes/safety_Commerce_df.csv',index_col='Unnamed: 0')
commerce_telecom=pd.read_csv('./webscrapes/telecom_Commerce_df.csv',index_col='Unnamed: 0')
commerce_transit=pd.read_csv('./webscrapes/trans_Commerce_df.csv',index_col='Unnamed: 0')
commerce=pd.concat([commerce_energy,commerce_food,commerce_haz,commerce_health,commerce_police,commerce_safety,commerce_telecom,commerce_transit])
commerce.head()
# Out:
#                  name                                        address  \
# 0            QuikTrip        ['30839 Hwy 441', 'Commerce, GA 30529']
# 1           Race Trac      ['30548 Hwy 441 S', 'Commerce, GA 30529']
# 2  Racetrac Petroleum  ['30580 Highway 441 S', 'Commerce, GA 30529']
# 3          BP Station  ['30605 Highway 441 S', 'Commerce, GA 30529']
# 4              Murphy  ['30985 Highway 441 S', 'Commerce, GA 30529']
#
#      phone_number  location_latitude  location_longitude  is_closed      city  \
# 0  (706) 335-5316          34.249954          -83.459771      False  Commerce
# 1             NaN          34.257656          -83.464488      False  Commerce
# 2  (706) 336-5808          34.257076          -83.464668      False  Commerce
# 3  (706) 335-9280          34.253761          -83.462326      False  Commerce
# 4  (706) 336-0006          34.246800          -83.458540      False  Commerce
#
#    zip_code      category                                      FEMA_category
# ...

# %%
conyers_energy=pd.read_csv('./webscrapes/energy_Conyers_df.csv',index_col='Unnamed: 0')
conyers_food=pd.read_csv('./webscrapes/food_Conyers_df.csv',index_col='Unnamed: 0')
conyers_haz=pd.read_csv('./webscrapes/haz_Conyers_df.csv',index_col='Unnamed: 0')
conyers_health=pd.read_csv('./webscrapes/health_Conyers_df.csv',index_col='Unnamed: 0')
conyers_police=pd.read_csv('./webscrapes/police_Conyers_df.csv',index_col='Unnamed: 0')
conyers_safety=pd.read_csv('./webscrapes/safety_Conyers_df.csv',index_col='Unnamed: 0')
conyers_telecom=pd.read_csv('./webscrapes/telecom_Conyers_df.csv',index_col='Unnamed: 0')
conyers_transit=pd.read_csv('./webscrapes/trans_Conyers_df.csv',index_col='Unnamed: 0')
conyers=pd.concat([conyers_energy,conyers_food,conyers_haz,conyers_health,conyers_police,conyers_safety,conyers_telecom,conyers_transit])
conyers.head()
# Out:
#                        name  \
# 0  Elite Electric Solutions
# 1                  Quiktrip
# 2         Handy Electrician
# 3          Cameron Electric
# 4                  RaceTrac
#
#                                              address    phone_number  \
# 0        ['2315 Benji Blvd SE', 'Conyers, GA 30013']  (770) 760-7777
# 1          ['1340 Klondike Rd', 'Conyers, GA 30094']  (770) 602-4596
# 2  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...  (678) 873-5674
# 3        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 4           ['1744 Hwy 138 SW', 'Conyers, GA 30012']  (770) 760-8224
#
#    location_latitude  location_longitude  is_closed     city  zip_code  \
# 0          33.611803          -83.986815      False  Conyers   30013.0
# 1          33.664434          -84.031999      False  Conyers   30094.0
# 2          33.745860          -84.358690      False  Atlanta   30316.0
# 3          33.928235          -84.307313      False  Atlanta   30338.0
# ...

# %%
cumming_energy=pd.read_csv('./webscrapes/energy_Cumming_df.csv',index_col='Unnamed: 0')
cumming_food=pd.read_csv('./webscrapes/food_Cumming_df.csv',index_col='Unnamed: 0')
cumming_haz=pd.read_csv('./webscrapes/haz_Cumming_df.csv',index_col='Unnamed: 0')
cumming_health=pd.read_csv('./webscrapes/health_Cumming_df.csv',index_col='Unnamed: 0')
cumming_police=pd.read_csv('./webscrapes/police_Cumming_df.csv',index_col='Unnamed: 0')
cumming_safety=pd.read_csv('./webscrapes/safety_Cumming_df.csv',index_col='Unnamed: 0')
cumming_telecom=pd.read_csv('./webscrapes/telecom_Cumming_df.csv',index_col='Unnamed: 0')
cumming_transit=pd.read_csv('./webscrapes/trans_Cumming_df.csv',index_col='Unnamed: 0')
cumming=pd.concat([cumming_energy,cumming_food,cumming_haz,cumming_health,cumming_police,cumming_safety,cumming_telecom,cumming_transit])
cumming.head()
# Out:
#                                                 name  \
# 0                             Mr. Value Electricians
# 1                                   Costco Wholesale
# 2  TE Certified Electrical, Plumbing, Heating & C...
# 3                                  Big Frog Electric
# 4                                 Arc Angel Electric
#
#                                              address    phone_number  \
# 0  ['520 Pirkle Ferry Rd', 'Ste E', 'Cumming, GA ...  (770) 894-1566
# 1  ['1211 Bald Ridge Marina Rd', 'Cumming, GA 300...  (470) 239-6610
# 2       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 3               ['36 E Main St', 'Buford, GA 30518']  (770) 559-9009
# 4   ['2130 Ronald Reagan Blvd', 'Cumming, GA 30041']  (770) 889-9243
#
#    location_latitude  location_longitude  is_closed     city  zip_code  \
# 0          34.207489          -84.130411      False  Cumming   30040.0
# 1          34.213349          -84.116581      False  Cumming   30041.0
# ...

# %%
dalton_energy=pd.read_csv('./webscrapes/energy_Dalton_df.csv',index_col='Unnamed: 0')
dalton_food=pd.read_csv('./webscrapes/food_Dalton_df.csv',index_col='Unnamed: 0')
dalton_haz=pd.read_csv('./webscrapes/haz_Dalton_df.csv',index_col='Unnamed: 0')
dalton_health=pd.read_csv('./webscrapes/health_Dalton_df.csv',index_col='Unnamed: 0')
dalton_police=pd.read_csv('./webscrapes/police_Dalton_df.csv',index_col='Unnamed: 0')
dalton_safety=pd.read_csv('./webscrapes/safety_Dalton_df.csv',index_col='Unnamed: 0')
dalton_telecom=pd.read_csv('./webscrapes/telecom_Dalton_df.csv',index_col='Unnamed: 0')
dalton_transit=pd.read_csv('./webscrapes/trans_Dalton_df.csv',index_col='Unnamed: 0')
dalton=pd.concat([dalton_energy,dalton_food,dalton_haz,dalton_health,dalton_police,dalton_safety,dalton_telecom,dalton_transit])
dalton.head()
# Out:
#                      name                                       address  \
# 0                Racetrac     ['1511 W Walnut Ave', 'Dalton, GA 30720']
# 1     Pilot Travel Center    ['243 Connector 3 SW', 'Dalton, GA 30720']
# 2     Pilot Travel Center  ['142 Carbondale Rd SW', 'Dalton, GA 30721']
# 3              BproXpress   ['1400 N Thornton Ave', 'Dalton, GA 30720']
# 4  Murphy USA Store #7019        ['885 Shugart Rd', 'Dalton, GA 30720']
#
#      phone_number  location_latitude  location_longitude  is_closed    city  \
# 0  (706) 277-1270          34.760120          -84.996800      False  Dalton
# 1  (706) 277-7934          34.687382          -85.000056      False  Dalton
# 2  (706) 370-4060          34.655571          -84.980115      False  Dalton
# 3  (706) 671-1400          34.792918          -84.983085      False  Dalton
# 4  (706) 278-0261          34.791478          -84.997143      False  Dalton
#
#    zip_code            category  \
# 0     30720  Convenience Stores
# ...

# %%
douglasville_energy=pd.read_csv('./webscrapes/energy_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_food=pd.read_csv('./webscrapes/food_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_haz=pd.read_csv('./webscrapes/haz_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_health=pd.read_csv('./webscrapes/health_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_police=pd.read_csv('./webscrapes/police_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_safety=pd.read_csv('./webscrapes/safety_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_telecom=pd.read_csv('./webscrapes/telecom_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville_transit=pd.read_csv('./webscrapes/trans_Douglasville_df.csv',index_col='Unnamed: 0')
douglasville=pd.concat([douglasville_energy,douglasville_food,douglasville_haz,douglasville_health,douglasville_police,douglasville_safety,douglasville_telecom,douglasville_transit])
douglasville.head()
# Out:
#                      name                                            address  \
# 0                  Kroger  ['3875 Chapel Hill Rd', 'Douglasville, GA 30135']
# 1                RaceTrac       ['9294 Highway 5', 'Douglasville, GA 30134']
# 2  Full Circle Electrical                         ['Douglasville, GA 30135']
# 3     JEFF ELECTRIC CORP.  ['1270 Caroline St NE', 'Ste D104', 'Atlanta, ...
# 4                Quiktrip     ['2042 Fairburn Rd', 'Douglasville, GA 30135']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (770) 947-7144          33.699697          -84.718214      False
# 1  (678) 838-1538          33.729770          -84.761540      False
# 2  (678) 758-8621          33.718200          -84.764680      False
# 3  (404) 775-4891          33.758584          -84.347345      False
# 4  (678) 715-3364          33.749870          -84.710483      False
#
#            city  zip_code            category  \
# ...

# %%
dunwoody_energy=pd.read_csv('./webscrapes/energy_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_food=pd.read_csv('./webscrapes/food_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_haz=pd.read_csv('./webscrapes/haz_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_health=pd.read_csv('./webscrapes/health_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_police=pd.read_csv('./webscrapes/police_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_safety=pd.read_csv('./webscrapes/safety_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_telecom=pd.read_csv('./webscrapes/telecom_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody_transit=pd.read_csv('./webscrapes/trans_Dunwoody_df.csv',index_col='Unnamed: 0')
dunwoody=pd.concat([dunwoody_energy,dunwoody_food,dunwoody_haz,dunwoody_health,dunwoody_police,dunwoody_safety,dunwoody_telecom,dunwoody_transit])
dunwoody.head()
# Out:
#                                                 name  \
# 0                                   Cameron Electric
# 1                                             Costco
# 2  TE Certified Electrical, Plumbing, Heating & C...
# 3                                           QuikTrip
# 4                                  Aardvark Electric
#
#                                              address    phone_number  \
# 0        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 1  ['6350 Peachtree Dunwoody Rd NE', 'Atlanta, GA...  (770) 352-8672
# 2       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 3     ['7884 Roswell Rd', 'Sandy Springs, GA 30350']  (770) 390-9683
# 4                              ['Atlanta, GA 30329']  (404) 806-6851
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          33.928235          -84.307313      False        Atlanta     30338
# ...

# %%
duluth_energy=pd.read_csv('./webscrapes/energy_Duluth_df.csv',index_col='Unnamed: 0')
duluth_food=pd.read_csv('./webscrapes/food_Duluth_df.csv',index_col='Unnamed: 0')
duluth_haz=pd.read_csv('./webscrapes/haz_Duluth_df.csv',index_col='Unnamed: 0')
duluth_health=pd.read_csv('./webscrapes/health_Duluth_df.csv',index_col='Unnamed: 0')
duluth_police=pd.read_csv('./webscrapes/police_Duluth_df.csv',index_col='Unnamed: 0')
duluth_safety=pd.read_csv('./webscrapes/safety_Duluth_df.csv',index_col='Unnamed: 0')
duluth_telecom=pd.read_csv('./webscrapes/telecom_Duluth_df.csv',index_col='Unnamed: 0')
duluth_transit=pd.read_csv('./webscrapes/trans_Duluth_df.csv',index_col='Unnamed: 0')
duluth=pd.concat([duluth_energy,duluth_food,duluth_haz,duluth_health,duluth_police,duluth_safety,duluth_telecom,duluth_transit])
duluth.head()
# Out:
#                                                 name  \
# 0                                             Kroger
# 1  TE Certified Electrical, Plumbing, Heating & C...
# 2                                           QuikTrip
# 3                                     Socket Doctors
# 4                                           QuikTrip
#
#                                              address    phone_number  \
# 0        ['6555 Sugarloaf Pkwy', 'Duluth, GA 30097']  (770) 814-7190
# 1       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 2        ['3495 Satellite Blvd', 'Duluth, GA 30096']  (770) 497-8933
# 3  ['4850 Golden Pkwy', 'Ste B311', 'Buford, GA 3...  (678) 835-9300
# 4        ['2571 Satellite Blvd', 'Duluth, GA 30096']  (770) 232-0272
#
#    location_latitude  location_longitude  is_closed     city  zip_code  \
# 0          33.998059          -84.089943      False   Duluth     30097
# 1          34.018702          -84.328872      False  Roswell     30075
# ...

# %%
east_point_energy=pd.read_csv('./webscrapes/energy_East_Point_df.csv',index_col='Unnamed: 0')
east_point_food=pd.read_csv('./webscrapes/food_East_Point_df.csv',index_col='Unnamed: 0')
east_point_haz=pd.read_csv('./webscrapes/haz_East_Point_df.csv',index_col='Unnamed: 0')
east_point_health=pd.read_csv('./webscrapes/health_East_Point_df.csv',index_col='Unnamed: 0')
east_point_police=pd.read_csv('./webscrapes/police_East_Point_df.csv',index_col='Unnamed: 0')
east_point_safety=pd.read_csv('./webscrapes/safety_East_Point_df.csv',index_col='Unnamed: 0')
east_point_telecom=pd.read_csv('./webscrapes/telecom_East_Point_df.csv',index_col='Unnamed: 0')
east_point_transit=pd.read_csv('./webscrapes/trans_East_Point_df.csv',index_col='Unnamed: 0')
east_point=pd.concat([east_point_energy,east_point_food,east_point_haz,east_point_health,east_point_police,east_point_safety,east_point_telecom,east_point_transit])
east_point.head()
# Out:
#                   name                                            address  \
# 0    Handy Electrician  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...
# 1  JEFF ELECTRIC CORP.  ['1270 Caroline St NE', 'Ste D104', 'Atlanta, ...
# 2             RaceTrac   ['3503 Camp Creek Pkwy', 'East Point, GA 30344']
# 3       Estes Services       ['3981 Tradeport Blvd', 'Atlanta, GA 30354']
# 4     Cameron Electric        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (678) 873-5674          33.745860          -84.358690      False
# 1  (404) 775-4891          33.758584          -84.347345      False
# 2  (404) 349-9871          33.654275          -84.503962      False
# 3  (404) 362-6965          33.646239          -84.395519      False
# 4  (404) 891-6448          33.928235          -84.307313      False
#
#          city  zip_code                         category  \
# ...

# %%
eastman_energy=pd.read_csv('./webscrapes/energy_Eastman_df.csv',index_col='Unnamed: 0')
eastman_food=pd.read_csv('./webscrapes/food_Eastman_df.csv',index_col='Unnamed: 0')
eastman_health=pd.read_csv('./webscrapes/health_Eastman_df.csv',index_col='Unnamed: 0')
eastman_police=pd.read_csv('./webscrapes/police_Eastman_df.csv',index_col='Unnamed: 0')
eastman_safety=pd.read_csv('./webscrapes/safety_Eastman_df.csv',index_col='Unnamed: 0')
eastman_telecom=pd.read_csv('./webscrapes/telecom_Eastman_df.csv',index_col='Unnamed: 0')
eastman_transit=pd.read_csv('./webscrapes/trans_Eastman_df.csv',index_col='Unnamed: 0')
eastman=pd.concat([eastman_energy,eastman_food,eastman_health,eastman_police,eastman_safety,eastman_telecom,eastman_transit])
eastman.head()
# Out:
#                               name  \
# 0               Love's Travel Stop
# 1              Pilot Travel Center
# 2       Friendly Gus Travel Center
# 3                               BP
# 4  Zaidee Corner Store & Resturant
#
#                                           address    phone_number  \
# 0            ['3009 Hwy 257', 'Dublin, GA 31021']  (478) 296-1368
# 1             ['2185 US 441', 'Dublin, GA 31021']  (478) 275-2143
# 2    ['1603 Ga Highway 19 S', 'Dublin, GA 31021']  (478) 272-2256
# 3       ['2167 US Hwy 441 S', 'Dublin, GA 31021']  (478) 274-1000
# 4  ['11881 Georgia Hwy 46', 'Soperton, GA 30457']  (912) 529-4474
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          32.496140          -82.981690      False    Dublin   31021.0
# 1          32.490210          -82.934187      False    Dublin   31021.0
# 2          32.482719          -82.896236      False    Dublin   31021.0
# ...

# %%
folkston_energy=pd.read_csv('./webscrapes/energy_Folkston_df.csv',index_col='Unnamed: 0')
folkston_food=pd.read_csv('./webscrapes/food_Folkston_df.csv',index_col='Unnamed: 0')
folkston_haz=pd.read_csv('./webscrapes/haz_Folkston_df.csv',index_col='Unnamed: 0')
folkston_health=pd.read_csv('./webscrapes/health_Folkston_df.csv',index_col='Unnamed: 0')
folkston_police=pd.read_csv('./webscrapes/police_Folkston_df.csv',index_col='Unnamed: 0')
folkston_safety=pd.read_csv('./webscrapes/safety_Folkston_df.csv',index_col='Unnamed: 0')
folkston_telecom=pd.read_csv('./webscrapes/telecom_Folkston_df.csv',index_col='Unnamed: 0')
folkston_transit=pd.read_csv('./webscrapes/trans_Folkston_df.csv',index_col='Unnamed: 0')
folkston=pd.concat([folkston_energy,folkston_food,folkston_haz,folkston_health,folkston_police,folkston_safety,folkston_telecom,folkston_transit])
folkston.head()
# Out:
#                               name  \
# 0              Pilot Travel Center
# 1           Petro Stopping Centers
# 2         Franklin Equipment Sales
# 3                  Murphy USA 6634
# 4  American Electrical Contracting
#
#                                              address    phone_number  \
# 0      ["491 St Mary's Rd", 'Saint Marys, GA 31558']  (912) 576-5424
# 1         ['1105 E King Ave', 'Kingsland, GA 31548']  (912) 882-3111
# 2              ['551797 US 1', 'Hilliard, FL 32046']  (904) 675-9129
# 3  ['6438 Ga Highway 40 E', 'Saint Marys, GA 31558']  (912) 882-3570
# 4  ['5065 St Augustine Rd', 'Ste 3', 'Jacksonvill...  (904) 737-9046
#
#    location_latitude  location_longitude  is_closed          city  zip_code  \
# 0          30.760071          -81.648475      False   Saint Marys     31558
# 1          30.795250          -81.666000      False     Kingsland     31548
# 2          30.692150          -81.919150      False      Hilliard     32046
# ...

# %%
gainesville_energy=pd.read_csv('./webscrapes/energy_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_food=pd.read_csv('./webscrapes/food_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_haz=pd.read_csv('./webscrapes/haz_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_health=pd.read_csv('./webscrapes/health_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_police=pd.read_csv('./webscrapes/police_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_safety=pd.read_csv('./webscrapes/safety_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_telecom=pd.read_csv('./webscrapes/telecom_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville_transit=pd.read_csv('./webscrapes/trans_Gainesville_df.csv',index_col='Unnamed: 0')
gainesville=pd.concat([gainesville_energy,gainesville_food,gainesville_haz,gainesville_health,gainesville_police,gainesville_safety,gainesville_telecom,gainesville_transit])
gainesville.head()
# Out:
#                            name  \
# 0                      QuikTrip
# 1                      RaceTrac
# 2             Big Frog Electric
# 3  Whitmire Plumbing & Electric
# 4                      RaceTrac
#
#                                              address    phone_number  \
# 0  ['1910 Jesse Jewell Pkwy NE', 'Gainesville, GA...  (770) 287-1607
# 1        ['1450 McEver Rd', 'Gainesville, GA 30504']  (770) 534-1920
# 2               ['36 E Main St', 'Buford, GA 30518']  (770) 559-9009
# 3  ['531 Jesse Jewell Pkwy SW', 'Gainesville, GA ...  (770) 531-1010
# 4     ['2410 Cornelia Hwy', 'Gainesville, GA 30501']  (770) 287-3659
#
#    location_latitude  location_longitude  is_closed         city  zip_code  \
# 0          34.312489          -83.795808      False  Gainesville   30501.0
# 1          34.282070          -83.871986      False  Gainesville   30504.0
# 2          34.120510          -84.005698      False       Buford   30518.0
# ...

# %%
griffin_energy=pd.read_csv('./webscrapes/energy_Griffin_df.csv',index_col='Unnamed: 0')
griffin_food=pd.read_csv('./webscrapes/food_Griffin_df.csv',index_col='Unnamed: 0')
griffin_haz=pd.read_csv('./webscrapes/haz_Griffin_df.csv',index_col='Unnamed: 0')
griffin_health=pd.read_csv('./webscrapes/health_Griffin_df.csv',index_col='Unnamed: 0')
griffin_police=pd.read_csv('./webscrapes/police_Griffin_df.csv',index_col='Unnamed: 0')
griffin_safety=pd.read_csv('./webscrapes/safety_Griffin_df.csv',index_col='Unnamed: 0')
griffin_telecom=pd.read_csv('./webscrapes/telecom_Griffin_df.csv',index_col='Unnamed: 0')
griffin_transit=pd.read_csv('./webscrapes/trans_Griffin_df.csv',index_col='Unnamed: 0')
griffin=pd.concat([griffin_energy,
griffin_food,
griffin_haz,
griffin_health,
griffin_police,
griffin_safety,
griffin_telecom,
griffin_transit])
griffin.head()
# Out:
#                               name  \
# 0                 Hammond Services
# 1  B & B Electrical Service Repair
# 2                     Spalding Gas
# 3          MARATHON JP Gas Station
# 4   Plugged In Electrical Services
#
#                                       address    phone_number  \
# 0  ['644 E McIntosh Rd', 'Griffin, GA 30223']  (470) 369-0993
# 1      ['246 Steele Rd', 'Griffin, GA 30223']  (404) 914-4281
# 2   ['415 W Solomon St', 'Griffin, GA 30223']  (770) 228-8484
# 3      ['301 Wilson Rd', 'Griffin, GA 30224']  (770) 776-2386
# 4   ['77 Summerfield Dr', 'Senoia, GA 30276']  (404) 277-9708
#
#    location_latitude  location_longitude  is_closed     city  zip_code  \
# 0          33.279965          -84.261671      False  Griffin   30223.0
# 1          33.301776          -84.333244      False  Griffin   30223.0
# 2          33.249000          -84.269320      False  Griffin   30223.0
# 3          33.232387          -84.231769      False  Griffin   30224.0
# ...

# %%
guyton_energy=pd.read_csv('./webscrapes/energy_Guyton_df.csv',index_col='Unnamed: 0')
guyton_food=pd.read_csv('./webscrapes/food_Guyton_df.csv',index_col='Unnamed: 0')
guyton_haz=pd.read_csv('./webscrapes/haz_Guyton_df.csv',index_col='Unnamed: 0')
guyton_health=pd.read_csv('./webscrapes/health_Guyton_df.csv',index_col='Unnamed: 0')
guyton_police=pd.read_csv('./webscrapes/police_Guyton_df.csv',index_col='Unnamed: 0')
guyton_safety=pd.read_csv('./webscrapes/safety_Guyton_df.csv',index_col='Unnamed: 0')
guyton_telecom=pd.read_csv('./webscrapes/telecom_Guyton_df.csv',index_col='Unnamed: 0')
guyton_transit=pd.read_csv('./webscrapes/trans_Guyton_df.csv',index_col='Unnamed: 0')
guyton=pd.concat([guyton_energy,guyton_food,guyton_haz,guyton_health,guyton_police,guyton_safety,guyton_telecom,guyton_transit])
guyton.head()
# Out:
#                      name                                            address  \
# 0                enmarket         ['1283 Hwy 21 S', 'Springfield, GA 31329']
# 1                Parker's           ['100 Central Blvd', 'Guyton, GA 31312']
# 2       Rinku Convenience              ['507 Church St', 'Guyton, GA 31312']
# 3  MacK's Service Station           ['112 Central Blvd', 'Guyton, GA 31312']
# 4              Zip-N-Food  ['7462 Stilson Leefield Rd', 'Brooklet, GA 304...
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 754-7379          32.351592          -81.296701      False
# 1  (912) 772-9131          32.330139          -81.392067      False
# 2  (912) 772-5190          32.337093          -81.392685      False
# 3  (912) 772-3351          32.332130          -81.392776      False
# 4  (912) 842-4222          32.418967          -81.612910      False
#
#           city  zip_code            category  \
# ...

# %%
hinesville_energy=pd.read_csv('./webscrapes/energy_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_food=pd.read_csv('./webscrapes/food_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_haz=pd.read_csv('./webscrapes/haz_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_health=pd.read_csv('./webscrapes/health_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_police=pd.read_csv('./webscrapes/police_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_safety=pd.read_csv('./webscrapes/safety_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_telecom=pd.read_csv('./webscrapes/telecom_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville_transit=pd.read_csv('./webscrapes/trans_Hinesville_df.csv',index_col='Unnamed: 0')
hinesville=pd.concat([hinesville_energy,hinesville_food,hinesville_haz,hinesville_health,hinesville_police,hinesville_safety,hinesville_telecom,hinesville_transit])
hinesville.head()
# Out:
#                  name                                            address  \
# 0  Canoochee Electric                           ['Hinesville, GA 31313']
# 1     Dawson Electric           ['1389 Shaw Rd', 'Hinesville, GA 31313']
# 2            Parker's      ['58 Old Sunbury Rd', 'Hinesville, GA 31313']
# 3            Parker's         ['2475 Hwy 196 W', 'Hinesville, GA 31313']
# 4          ProLectric  ['6606 Abercorn St', 'Ste 120', 'Savannah, GA ...
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (808) 342-0134          31.825880          -81.620540      False
# 1  (912) 369-7596          31.796450          -81.614110      False
# 2  (912) 876-5015          31.859440          -81.563635      False
# 3  (912) 369-7771          31.814721          -81.650469      False
# 4  (912) 210-1100          32.016610          -81.111650      False
#
#          city  zip_code            category  \
# 0  Hinesville     31313        Electricians
# ...

# %%
jasper_energy=pd.read_csv('./webscrapes/energy_Jasper_df.csv',index_col='Unnamed: 0')
jasper_food=pd.read_csv('./webscrapes/food_Jasper_df.csv',index_col='Unnamed: 0')
jasper_haz=pd.read_csv('./webscrapes/haz_Jasper_df.csv',index_col='Unnamed: 0')
jasper_health=pd.read_csv('./webscrapes/health_Jasper_df.csv',index_col='Unnamed: 0')
jasper_police=pd.read_csv('./webscrapes/police_Jasper_df.csv',index_col='Unnamed: 0')
jasper_safety=pd.read_csv('./webscrapes/safety_Jasper_df.csv',index_col='Unnamed: 0')
jasper_telecom=pd.read_csv('./webscrapes/telecom_Jasper_df.csv',index_col='Unnamed: 0')
jasper_transit=pd.read_csv('./webscrapes/trans_Jasper_df.csv',index_col='Unnamed: 0')
jasper=pd.concat([jasper_energy,jasper_food,jasper_haz,jasper_health,jasper_police,jasper_safety,jasper_telecom,jasper_transit])
jasper.head()
# Out:
#                         name                                          address  \
# 0                     Kroger  ['115 Bill Wigington Pkwy', 'Jasper, GA 30143']
# 1                   QuikTrip             ['3353 Camp Rd', 'Jasper, GA 30143']
# 2                   RaceTrac      ['303 Interstate S Dr', 'Jasper, GA 30143']
# 3  H & H Electric & Security         ['15640 FIncher Rd', 'Jasper, GA 30143']
# 4         Mountainview Citgo              ['29A Cove Rd', 'Jasper, GA 30143']
#
#      phone_number  location_latitude  location_longitude  is_closed    city  \
# 0  (706) 692-1200          34.466443          -84.462141      False  Jasper
# 1  (706) 301-9011          34.457000          -84.453110      False  Jasper
# 2  (770) 735-2036          34.397635          -84.414042      False  Jasper
# 3  (770) 735-1136          34.379202          -84.475978      False  Jasper
# 4  (706) 253-7377          34.472610          -84.422170      False  Jasper
#
# ...

# %%
johns_creek_energy=pd.read_csv('./webscrapes/energy_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_food=pd.read_csv('./webscrapes/food_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_haz=pd.read_csv('./webscrapes/haz_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_health=pd.read_csv('./webscrapes/health_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_police=pd.read_csv('./webscrapes/police_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_safety=pd.read_csv('./webscrapes/safety_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_telecom=pd.read_csv('./webscrapes/telecom_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek_transit=pd.read_csv('./webscrapes/trans_Johns_Creek_df.csv',index_col='Unnamed: 0')
johns_creek=pd.concat([johns_creek_energy,johns_creek_food,johns_creek_haz,johns_creek_health,johns_creek_police,johns_creek_safety,johns_creek_telecom,johns_creek_transit])
johns_creek.head()
# Out:
#                                                 name  \
# 0  TE Certified Electrical, Plumbing, Heating & C...
# 1                                           QuikTrip
# 2                                   Cameron Electric
# 3                                  Handy Electrician
# 4                                             Costco
#
#                                              address    phone_number  \
# 0       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 1      ['5255 Peachtree Pkwy', 'Norcross, GA 30092']  (770) 729-9668
# 2        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 3  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...  (678) 873-5674
# 4  ['6350 Peachtree Dunwoody Rd NE', 'Atlanta, GA...  (770) 352-8672
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          34.018702          -84.328872      False   Roswell     30075
# 1          33.977407          -84.218604      False  Norcross     30092
# ...

# %%
kennesaw_energy=pd.read_csv('./webscrapes/energy_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_food=pd.read_csv('./webscrapes/food_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_haz=pd.read_csv('./webscrapes/haz_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_health=pd.read_csv('./webscrapes/health_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_police=pd.read_csv('./webscrapes/police_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_safety=pd.read_csv('./webscrapes/safety_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_telecom=pd.read_csv('./webscrapes/telecom_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw_transit=pd.read_csv('./webscrapes/trans_Kennesaw_df.csv',index_col='Unnamed: 0')
kennesaw=pd.concat([kennesaw_energy,
kennesaw_food,
kennesaw_haz,
kennesaw_health,
kennesaw_police,
kennesaw_safety,
kennesaw_telecom,
kennesaw_transit])
kennesaw.head()
# Out:
#                                                 name  \
# 0      Reliable Heating & Air, Plumbing & Electrical
# 1                                           Quiktrip
# 2  TE Certified Electrical, Plumbing, Heating & C...
# 3                                           QuikTrip
# 4                                           QuikTrip
#
#                                              address    phone_number  \
# 0  ['1305 Chastain Rd NW', 'Ste 500', 'Kennesaw, ...  (770) 594-9969
# 1        ['2761 Cobb Pkwy NW', 'Kennesaw, GA 30152']  (678) 581-1544
# 2       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 3  ['1400 Ernest W Barrett Pkwy NW', 'Kennesaw, G...  (470) 336-4990
# 4      ['4340 Bells Ferry Rd', 'Kennesaw, GA 30144']  (770) 591-0679
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          34.024035          -84.585918      False  Kennesaw   30144.0
# 1          34.019783          -84.621925      False  Kennesaw   30152.0
# ...

# %%
lagrange_energy=pd.read_csv('./webscrapes/energy_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_food=pd.read_csv('./webscrapes/food_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_haz=pd.read_csv('./webscrapes/haz_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_health=pd.read_csv('./webscrapes/health_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_police=pd.read_csv('./webscrapes/police_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_safety=pd.read_csv('./webscrapes/safety_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_telecom=pd.read_csv('./webscrapes/telecom_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange_transit=pd.read_csv('./webscrapes/trans_LaGrange_df.csv',index_col='Unnamed: 0')
lagrange=pd.concat([lagrange_energy,
lagrange_food,
lagrange_haz,
lagrange_health,
lagrange_police,
lagrange_safety,
lagrange_telecom,
lagrange_transit])
lagrange.head()
# Out:
#                                 name  \
# 0                           Racetrac
# 1                             Valero
# 2  Shell Gas station And Summit mart
# 3                 Love's Travel Stop
# 4                 Valero Gas Station
#
#                                            address    phone_number  \
# 0    ['1517 Lafayette Pkwy', 'LaGrange, GA 30240']  (706) 812-8595
# 1        ['2725 Roanoke Rd', 'LaGrange, GA 30240']  (706) 884-5820
# 2       ['4630 Hamilton Rd', 'LaGrange, GA 30241']  (706) 845-0806
# 3  ['1621 Bass Cross Rd', 'Hogansville, GA 30230']  (706) 637-4311
# 4         ['101 Hoffman Dr', 'LaGrange, GA 30241']  (706) 882-8760
#
#    location_latitude  location_longitude  is_closed         city  zip_code  \
# 0          33.042848          -84.983854      False     LaGrange     30240
# 1          33.033493          -85.095906      False     LaGrange     30240
# 2          32.960450          -84.950268      False     LaGrange     30241
# ...

# %%
lawrenceville_energy=pd.read_csv('./webscrapes/energy_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_food=pd.read_csv('./webscrapes/food_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_haz=pd.read_csv('./webscrapes/haz_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_health=pd.read_csv('./webscrapes/health_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_police=pd.read_csv('./webscrapes/police_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_safety=pd.read_csv('./webscrapes/safety_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_telecom=pd.read_csv('./webscrapes/telecom_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville_transit=pd.read_csv('./webscrapes/trans_Lawrenceville_df.csv',index_col='Unnamed: 0')
lawrenceville=pd.concat([lawrenceville_energy,
lawrenceville_food,
lawrenceville_haz,
lawrenceville_health,
lawrenceville_police,
lawrenceville_safety,
lawrenceville_telecom,
lawrenceville_transit])
lawrenceville.head()
# Out:
#                            name  \
# 0                      Racetrac
# 1  Kalahari Electrical Services
# 2                      QuikTrip
# 3             Big Frog Electric
# 4                      RaceTrac
#
#                                              address    phone_number  \
# 0       ['444 W Pike St', 'Lawrenceville, GA 30046']  (770) 962-5654
# 1  ['4790 Sugarloaf Pkwy', 'Lawrenceville, GA 300...  (678) 665-2309
# 2       ['741 W Pike St', 'Lawrenceville, GA 30046']  (770) 995-1180
# 3               ['36 E Main St', 'Buford, GA 30518']  (770) 559-9009
# 4       ['624 Buford Dr', 'Lawrenceville, GA 30046']  (678) 442-6610
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          33.960658          -84.005401      False  Lawrenceville   30046.0
# 1          33.953800          -84.052220      False  Lawrenceville   30044.0
# 2          33.959076          -84.003186      False  Lawrenceville   30046.0
# ...

# %%
macon_energy=pd.read_csv('./webscrapes/energy_Macon_df.csv',index_col='Unnamed: 0')
macon_food=pd.read_csv('./webscrapes/food_Macon_df.csv',index_col='Unnamed: 0')
macon_haz=pd.read_csv('./webscrapes/haz_Macon_df.csv',index_col='Unnamed: 0')
macon_health=pd.read_csv('./webscrapes/health_Macon_df.csv',index_col='Unnamed: 0')
macon_police=pd.read_csv('./webscrapes/police_Macon_df.csv',index_col='Unnamed: 0')
macon_safety=pd.read_csv('./webscrapes/safety_Macon_df.csv',index_col='Unnamed: 0')
macon_telecom=pd.read_csv('./webscrapes/telecom_Macon_df.csv',index_col='Unnamed: 0')
macon_transit=pd.read_csv('./webscrapes/trans_Macon_df.csv',index_col='Unnamed: 0')
macon=pd.concat([macon_energy,
macon_food,
macon_haz,
macon_health,
macon_police,
macon_safety,
macon_telecom,
macon_transit])
macon.head()
# Out:
#                  name                                         address  \
# 0  Love's Travel Stop  ['1190 Frank Amerson Pkwy', 'Macon, GA 31216']
# 1             Raceway        ['4331 Pio Nono Ave', 'Macon, GA 31206']
# 2               Shell          ['6205 Zebulon Rd', 'Macon, GA 31210']
# 3         Flash Foods          ['1194 Forsyth St', 'Macon, GA 31201']
# 4          MetroPower              ['444 Plum St', 'Macon, GA 31201']
#
#      phone_number  location_latitude  location_longitude  is_closed   city  \
# 0  (478) 785-8715          32.717433          -83.733458      False  Macon
# 1  (478) 781-0853          32.784409          -83.666501      False  Macon
# 2  (478) 471-8304          32.880491          -83.764581      False  Macon
# 3  (478) 743-0877          32.835796          -83.640122      False  Macon
# 4  (478) 745-5400          32.832265          -83.628919      False  Macon
#
#    zip_code            category  \
# 0   31216.0        Gas Stations
# ...

# %%
marietta_energy=pd.read_csv('./webscrapes/energy_Marietta_df.csv',index_col='Unnamed: 0')
marietta_food=pd.read_csv('./webscrapes/food_Marietta_df.csv',index_col='Unnamed: 0')
marietta_haz=pd.read_csv('./webscrapes/haz_Marietta_df.csv',index_col='Unnamed: 0')
marietta_health=pd.read_csv('./webscrapes/health_Marietta_df.csv',index_col='Unnamed: 0')
marietta_police=pd.read_csv('./webscrapes/police_Marietta_df.csv',index_col='Unnamed: 0')
marietta_safety=pd.read_csv('./webscrapes/safety_Marietta_df.csv',index_col='Unnamed: 0')
marietta_telecom=pd.read_csv('./webscrapes/telecom_Marietta_df.csv',index_col='Unnamed: 0')
marietta_transit=pd.read_csv('./webscrapes/trans_Marietta_df.csv',index_col='Unnamed: 0')
marietta=pd.concat([marietta_energy,
marietta_food,
marietta_haz,
marietta_health,
marietta_police,
marietta_safety,
marietta_telecom,
marietta_transit])
marietta.head()
# Out:
#                                               name  \
# 0                           Lightning Bug Electric
# 1                            Lawson & Son Electric
# 2  Casteel Heating, Cooling, Plumbing & Electrical
# 3                     Majestic Plumbing & Electric
# 4                                    Ampt Electric
#
#                                              address    phone_number  \
# 0                             ['Marietta, GA 30066']  (404) 471-3847
# 1                             ['Marietta, GA 30062']  (470) 255-0349
# 2           ['2218 Canton Rd', 'Marietta, GA 30066']  (678) 723-6272
# 3       ['1634 Atlanta Rd SE', 'Marietta, GA 30060']  (404) 418-8140
# 4  ['1300 Mountain Retreat Way', 'Ste 110', 'Mari...  (678) 632-2678
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          34.037333          -84.464259      False  Marietta     30066
# 1          34.020615          -84.427460      False  Marietta     30062
# ...

# %%
milton_energy=pd.read_csv('./webscrapes/energy_Milton_df.csv',index_col='Unnamed: 0')
milton_food=pd.read_csv('./webscrapes/food_Milton_df.csv',index_col='Unnamed: 0')
milton_haz=pd.read_csv('./webscrapes/haz_Milton_df.csv',index_col='Unnamed: 0')
milton_health=pd.read_csv('./webscrapes/health_Milton_df.csv',index_col='Unnamed: 0')
milton_police=pd.read_csv('./webscrapes/police_Milton_df.csv',index_col='Unnamed: 0')
milton_safety=pd.read_csv('./webscrapes/safety_Milton_df.csv',index_col='Unnamed: 0')
milton_telecom=pd.read_csv('./webscrapes/telecom_Milton_df.csv',index_col='Unnamed: 0')
milton_transit=pd.read_csv('./webscrapes/trans_Milton_df.csv',index_col='Unnamed: 0')
milton=pd.concat([milton_energy,
milton_food,
milton_haz,
milton_health,
milton_police,
milton_safety,
milton_telecom,
milton_transit])
milton.head()
# Out:
#                                                 name  \
# 0  TE Certified Electrical, Plumbing, Heating & C...
# 1                                   Cameron Electric
# 2                                           QuikTrip
# 3                             Lightning Bug Electric
# 4                                  Big Frog Electric
#
#                                              address    phone_number  \
# 0       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 1        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 2  ['11700 Haynes Bridge Rd', 'Alpharetta, GA 300...  (770) 752-9890
# 3                             ['Marietta, GA 30066']  (404) 471-3847
# 4               ['36 E Main St', 'Buford, GA 30518']  (770) 559-9009
#
#    location_latitude  location_longitude  is_closed        city  zip_code  \
# 0          34.018702          -84.328872      False     Roswell   30075.0
# 1          33.928235          -84.307313      False     Atlanta   30338.0
# ...

# %%
milledgeville_energy=pd.read_csv('./webscrapes/energy_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_food=pd.read_csv('./webscrapes/food_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_haz=pd.read_csv('./webscrapes/haz_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_health=pd.read_csv('./webscrapes/health_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_police=pd.read_csv('./webscrapes/police_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_safety=pd.read_csv('./webscrapes/safety_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_telecom=pd.read_csv('./webscrapes/telecom_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville_transit=pd.read_csv('./webscrapes/trans_Milledgeville_df.csv',index_col='Unnamed: 0')
milledgeville=pd.concat([
milledgeville_energy,
milledgeville_food,
milledgeville_haz,
milledgeville_health,
milledgeville_police,
milledgeville_safety,
milledgeville_telecom,
milledgeville_transit])
milledgeville.head()
# Out:
#                                      name  \
# 0            Marathon Gas & Mishie's Mart
# 1                         Millegeville 76
# 2                             Qwik Stop 3
# 3  Wright Heating, Cooling and Electrical
# 4                  Roberts & Sons Propane
#
#                                              address    phone_number  \
# 0  ['208  Roberson Mill Rd', 'Milledgeville, GA 3...             NaN
# 1  ['155 Roberson Mill Rd', 'Milledgeville, GA 31...  (478) 452-7313
# 2  ['2653 N Columbia St', 'Milledgeville, GA 31061']  (478) 452-1945
# 3                        ['Milledgeville, GA 31061']  (478) 452-1148
# 4  ['149 Garrett Way NW', 'Milledgeville, GA 31061']  (478) 452-0514
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          33.096871          -83.258859      False  Milledgeville     31061
# 1          33.103626          -83.261263      False  Milledgeville     31061
# ...

# %%
newnan_energy=pd.read_csv('./webscrapes/energy_Newnan_df.csv',index_col='Unnamed: 0')
newnan_food=pd.read_csv('./webscrapes/food_Newnan_df.csv',index_col='Unnamed: 0')
newnan_haz=pd.read_csv('./webscrapes/haz_Newnan_df.csv',index_col='Unnamed: 0')
newnan_health=pd.read_csv('./webscrapes/health_Newnan_df.csv',index_col='Unnamed: 0')
newnan_police=pd.read_csv('./webscrapes/police_Newnan_df.csv',index_col='Unnamed: 0')
newnan_safety=pd.read_csv('./webscrapes/safety_Newnan_df.csv',index_col='Unnamed: 0')
newnan_telecom=pd.read_csv('./webscrapes/telecom_Newnan_df.csv',index_col='Unnamed: 0')
newnan_transit=pd.read_csv('./webscrapes/trans_Newnan_df.csv',index_col='Unnamed: 0')
newnan=pd.concat([newnan_energy,
newnan_food,
newnan_haz,
newnan_health,
newnan_police,
newnan_safety,
newnan_telecom,
newnan_transit])
newnan.head()
# Out:
#                   name                                            address  \
# 0         MC6 Electric  ['1002 Highway 16 W', 'Ste A', 'Newnan, GA 302...
# 1             Racetrac            ['1 Amlajack Blvd', 'Newnan, GA 30265']
# 2                Exxon       ['67 Market Square Way', 'Newnan, GA 30265']
# 3  Pilot Travel Center              ['1645 Hwy 29 S', 'Newnan, GA 30263']
# 4               Kroger  ['1751 Newnan Crossing Blvd E', 'Newnan, GA 30...
#
#      phone_number  location_latitude  location_longitude  is_closed    city  \
# 0  (678) 552-9399          33.409658          -84.841459      False  Newnan
# 1  (770) 251-5638          33.397450          -84.753590      False  Newnan
# 2  (770) 251-9011          33.378697          -84.739494      False  Newnan
# 3  (770) 252-3551          33.329612          -84.780860      False  Newnan
# 4  (678) 423-5841          33.377067          -84.751784      False  Newnan
#
# ...

# %%
peachtree_corner_energy=pd.read_csv('./webscrapes/energy_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_food=pd.read_csv('./webscrapes/food_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_haz=pd.read_csv('./webscrapes/haz_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_health=pd.read_csv('./webscrapes/health_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_police=pd.read_csv('./webscrapes/police_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_safety=pd.read_csv('./webscrapes/safety_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_telecom=pd.read_csv('./webscrapes/telecom_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner_transit=pd.read_csv('./webscrapes/trans_Peachtree_Corners_df.csv',index_col='Unnamed: 0')
peachtree_corner=pd.concat([peachtree_corner_energy,
peachtree_corner_food,
peachtree_corner_haz,
peachtree_corner_health,
peachtree_corner_police,
peachtree_corner_safety,
peachtree_corner_telecom,
peachtree_corner_transit])
peachtree_corner.head()
# Out:
#                                                 name  \
# 0  TE Certified Electrical, Plumbing, Heating & C...
# 1                                           QuikTrip
# 2                                   Cameron Electric
# 3                                           RaceTrac
# 4                                           QuikTrip
#
#                                              address    phone_number  \
# 0       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 1      ['5255 Peachtree Pkwy', 'Norcross, GA 30092']  (770) 729-9668
# 2        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 3   ['6875 Jimmy Carter Blvd', 'Norcross, GA 30071']  (770) 248-0083
# 4  ['3229 Peachtree Corners Cir', 'Peachtree Corn...  (770) 662-0537
#
#    location_latitude  location_longitude  is_closed               city  \
# 0          34.018702          -84.328872      False            Roswell
# 1          33.977407          -84.218604      False           Norcross
# ...

# %%
peachtree_city_energy=pd.read_csv('./webscrapes/energy_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_food=pd.read_csv('./webscrapes/food_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_haz=pd.read_csv('./webscrapes/haz_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_health=pd.read_csv('./webscrapes/health_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_police=pd.read_csv('./webscrapes/police_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_safety=pd.read_csv('./webscrapes/safety_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_telecom=pd.read_csv('./webscrapes/telecom_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city_transit=pd.read_csv('./webscrapes/trans_PeachtreeCity_df.csv',index_col='Unnamed: 0')
peachtree_city=pd.concat([peachtree_city_energy,
peachtree_city_food,
peachtree_city_haz,
peachtree_city_health,
peachtree_city_police,
peachtree_city_safety,
peachtree_city_telecom,
peachtree_city_transit])
peachtree_city.head()
# Out:
#                                                 name  \
# 0                                Powerworks Electric
# 1                     Plugged In Electrical Services
# 2                                   Glenloch Chevron
# 3                               Racetrac Gas Station
# 4  Electrical & Lighting Solutions of Peachtree City
#
#                                              address    phone_number  \
# 0                       ['Peachtree City, GA 30269']  (770) 689-9620
# 1          ['77 Summerfield Dr', 'Senoia, GA 30276']  (404) 277-9708
# 2  ['2000 Shakerag Hl', 'Ste A', 'Peachtree City,...  (770) 487-9009
# 3        ['2722 Hwy 54', 'Peachtree City, GA 30269']  (770) 487-7663
# 4    ['177 Fulton Park', 'Peachtree City, GA 30269']  (678) 916-9871
#
#    location_latitude  location_longitude  is_closed            city  zip_code  \
# 0          33.400400          -84.586410      False  Peachtree City   30269.0
# ...

# %%
rome_energy=pd.read_csv('./webscrapes/energy_Rome_df.csv',index_col='Unnamed: 0')
rome_food=pd.read_csv('./webscrapes/food_Rome_df.csv',index_col='Unnamed: 0')
rome_haz=pd.read_csv('./webscrapes/haz_Rome_df.csv',index_col='Unnamed: 0')
rome_health=pd.read_csv('./webscrapes/health_Rome_df.csv',index_col='Unnamed: 0')
rome_police=pd.read_csv('./webscrapes/police_Rome_df.csv',index_col='Unnamed: 0')
rome_safety=pd.read_csv('./webscrapes/safety_Rome_df.csv',index_col='Unnamed: 0')
rome_telecom=pd.read_csv('./webscrapes/telecom_Rome_df.csv',index_col='Unnamed: 0')
rome_transit=pd.read_csv('./webscrapes/trans_Rome_df.csv',index_col='Unnamed: 0')
rome=pd.concat([rome_energy,
rome_food,
rome_haz,
rome_health,
rome_police,
rome_safety,
rome_telecom,
rome_transit])
rome.head()
# Out:
#                                               name  \
# 0                                  Tanner Electric
# 1                                         Racetrac
# 2                                         Circle K
# 3  Casteel Heating, Cooling, Plumbing & Electrical
# 4                                            Mapco
#
#                                           address    phone_number  \
# 0         ['162 Terhune Rd SE', 'Rome, GA 30161']  (706) 290-1134
# 1  ['3006 Martha Berry Hwy NE', 'Rome, GA 30165']  (706) 295-3903
# 2     ['3070 Cedartown Hwy SW', 'Rome, GA 30161']  (706) 290-9495
# 3        ['2218 Canton Rd', 'Marietta, GA 30066']  (678) 723-6272
# 4          ['2500 Shorter Ave', 'Rome, GA 30165']  (706) 232-2736
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          34.182860          -85.072620      False      Rome     30161
# 1          34.308568          -85.172232      False      Rome     30165
# ...

# %%
roswell_energy=pd.read_csv('./webscrapes/energy_Roswell_df.csv',index_col='Unnamed: 0')
roswell_food=pd.read_csv('./webscrapes/food_Roswell_df.csv',index_col='Unnamed: 0')
roswell_haz=pd.read_csv('./webscrapes/haz_Roswell_df.csv',index_col='Unnamed: 0')
roswell_health=pd.read_csv('./webscrapes/health_Roswell_df.csv',index_col='Unnamed: 0')
roswell_police=pd.read_csv('./webscrapes/police_Roswell_df.csv',index_col='Unnamed: 0')
roswell_safety=pd.read_csv('./webscrapes/safety_Roswell_df.csv',index_col='Unnamed: 0')
roswell_telecom=pd.read_csv('./webscrapes/telecom_Roswell_df.csv',index_col='Unnamed: 0')
roswell_transit=pd.read_csv('./webscrapes/trans_Roswell_df.csv',index_col='Unnamed: 0')
roswell=pd.concat([roswell_energy,
roswell_food,
roswell_haz,
roswell_health,
roswell_police,
roswell_safety,
roswell_telecom,
roswell_transit])
roswell.head()
# Out:
#                                                 name  \
# 0  TE Certified Electrical, Plumbing, Heating & C...
# 1                      Mr. Electric of Metro Atlanta
# 2                                           QuikTrip
# 3                                          Race Trac
# 4                                           QuikTrip
#
#                                           address    phone_number  \
# 0    ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 1            ['715 Bush St', 'Roswell, GA 30075']  (770) 504-4929
# 2     ['20 E Crossville Rd', 'Roswell, GA 30075']  (770) 552-5515
# 3    ['420 E Crossville Rd', 'Roswell, GA 30075']             NaN
# 4  ['7884 Roswell Rd', 'Sandy Springs, GA 30350']  (770) 390-9683
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          34.018702          -84.328872      False        Roswell     30075
# 1          34.018989          -84.359332      False        Roswell     30075
# ...

# %%
saint_simons_island_energy=pd.read_csv('./webscrapes/energy_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_food=pd.read_csv('./webscrapes/food_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_haz=pd.read_csv('./webscrapes/haz_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_health=pd.read_csv('./webscrapes/health_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_police=pd.read_csv('./webscrapes/police_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_safety=pd.read_csv('./webscrapes/safety_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_telecom=pd.read_csv('./webscrapes/telecom_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island_transit=pd.read_csv('./webscrapes/trans_Saint_Simons_Island_df.csv',index_col='Unnamed: 0')
saint_simons_island=pd.concat([saint_simons_island_energy,
saint_simons_island_food,
saint_simons_island_haz,
saint_simons_island_health,
saint_simons_island_police,
saint_simons_island_safety,
saint_simons_island_telecom,
saint_simons_island_transit])
saint_simons_island.head()
# Out:
#                       name                                            address  \
# 0                 Circle K  ['3801 Frederica Rd', 'St Simons Island, GA 31...
# 1  Thaw's Electric Service  ['428 Arnold Rd', 'Saint Simons Island, GA 315...
# 2            HeRo Handyman                            ['Brunswick, GA 31523']
# 3     Friendly Express #22    ['3245 Cypress Mill Rd', 'Brunswick, GA 31525']
# 4   BP Friendly Express 62         ['1313 Demere Rd', 'St. Simons, GA 31522']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 634-8900          31.190172          -81.376932      False
# 1  (912) 638-9797          31.142550          -81.382530      False
# 2  (912) 223-4899          31.229013          -81.475600      False
# 3  (912) 265-5341          31.193680          -81.475792      False
# 4  (912) 638-8404          31.144429          -81.383245      False
#
#                   city  zip_code            category  \
# ...

# %%
sandy_springs_energy=pd.read_csv('./webscrapes/energy_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_food=pd.read_csv('./webscrapes/food_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_haz=pd.read_csv('./webscrapes/haz_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_health=pd.read_csv('./webscrapes/health_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_police=pd.read_csv('./webscrapes/police_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_safety=pd.read_csv('./webscrapes/safety_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_telecom=pd.read_csv('./webscrapes/telecom_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs_transit=pd.read_csv('./webscrapes/trans_Sandy_Springs_df.csv',index_col='Unnamed: 0')
sandy_springs=pd.concat([sandy_springs_energy,
sandy_springs_food,
sandy_springs_haz,
sandy_springs_health,
sandy_springs_police,
sandy_springs_safety,
sandy_springs_telecom,
sandy_springs_transit])
sandy_springs.head()
# Out:
#                                                 name  \
# 0                                           QuikTrip
# 1                                             Costco
# 2                                   Cameron Electric
# 3  TE Certified Electrical, Plumbing, Heating & C...
# 4                                           QuikTrip
#
#                                              address    phone_number  \
# 0     ['7884 Roswell Rd', 'Sandy Springs, GA 30350']  (770) 390-9683
# 1  ['6350 Peachtree Dunwoody Rd NE', 'Atlanta, GA...  (770) 352-8672
# 2        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 3       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 4    ['8200 Dunwoody Pl', 'Sandy Springs, GA 30350']  (770) 640-8157
#
#    location_latitude  location_longitude  is_closed           city  zip_code  \
# 0          33.973207          -84.358297      False  Sandy Springs     30350
# ...

# %%
savannah_energy=pd.read_csv('./webscrapes/energy_Savannah_df.csv',index_col='Unnamed: 0')
savannah_food=pd.read_csv('./webscrapes/food_Savannah_df.csv',index_col='Unnamed: 0')
savannah_haz=pd.read_csv('./webscrapes/haz_Savannah_df.csv',index_col='Unnamed: 0')
savannah_health=pd.read_csv('./webscrapes/health_Savannah_df.csv',index_col='Unnamed: 0')
savannah_police=pd.read_csv('./webscrapes/police_Savannah_df.csv',index_col='Unnamed: 0')
savannah_safety=pd.read_csv('./webscrapes/safety_Savannah_df.csv',index_col='Unnamed: 0')
savannah_telecom=pd.read_csv('./webscrapes/telecom_Savannah_df.csv',index_col='Unnamed: 0')
savannah_transit=pd.read_csv('./webscrapes/trans_Savannah_df.csv',index_col='Unnamed: 0')
savannah=pd.concat([savannah_energy,
savannah_food,
savannah_haz,
savannah_health,
savannah_police,
savannah_safety,
savannah_telecom,
savannah_transit])
savannah.head()
# Out:
#                                  name  \
# 0                            Parker's
# 1  Mr. Electric of The Coastal Empire
# 2                            Parker's
# 3                            Parker's
# 4                          ProLectric
#
#                                              address    phone_number  \
# 0           ['222 Drayton St', 'Savannah, GA 31401']  (912) 233-1000
# 1            ['2134 Shell Rd', 'Savannah, GA 31404']  (912) 250-6671
# 2      ['325 Ml King Jr Blvd', 'Savannah, GA 31401']  (912) 447-0023
# 3      ['1910 E President St', 'Savannah, GA 31404']  (912) 232-5602
# 4  ['6606 Abercorn St', 'Ste 120', 'Savannah, GA ...  (912) 210-1100
#
#    location_latitude  location_longitude  is_closed      city  zip_code  \
# 0          32.075650          -81.091696      False  Savannah   31401.0
# 1          32.037160          -81.064020      False  Savannah   31404.0
# 2          32.075024          -81.099617      False  Savannah   31401.0
# ...

# %%
statesboro_energy=pd.read_csv('./webscrapes/energy_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_food=pd.read_csv('./webscrapes/food_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_haz=pd.read_csv('./webscrapes/haz_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_health=pd.read_csv('./webscrapes/health_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_police=pd.read_csv('./webscrapes/police_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_safety=pd.read_csv('./webscrapes/safety_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_telecom=pd.read_csv('./webscrapes/telecom_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_transit=pd.read_csv('./webscrapes/trans_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro=pd.concat([statesboro_energy,
statesboro_food,
statesboro_haz,
statesboro_health,
statesboro_police,
statesboro_safety,
statesboro_telecom,
statesboro_transit])
statesboro.head()
# Out:
#               name                                            address  \
# 0         Parker's     ['24151 Highway 80 E', 'Statesboro, GA 30458']
# 1  Murphy USA 6759     ['729 Northside Dr E', 'Statesboro, GA 30458']
# 2         Parker's       ['1899 Chandler Rd', 'Statesboro, GA 30458']
# 3         Parker's           ['12399 US 301', 'Statesboro, GA 30458']
# 4   Gate Petroleum  ['33 Statesboro Mall', 'Ste 2', 'Statesboro, G...
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 212-2088          32.432842          -81.754728      False
# 1  (912) 489-2161          32.435971          -81.758784      False
# 2  (912) 681-7007          32.413367          -81.781716      False
# 3  (912) 225-1993          32.416249          -81.800783      False
# 4  (912) 764-7965          32.441750          -81.782654      False
#
#          city  zip_code            category  \
# 0  Statesboro   30458.0        Gas Stations
# ...

# %%
symrna_energy=pd.read_csv('./webscrapes/energy_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_food=pd.read_csv('./webscrapes/food_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_haz=pd.read_csv('./webscrapes/haz_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_health=pd.read_csv('./webscrapes/health_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_police=pd.read_csv('./webscrapes/police_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_safety=pd.read_csv('./webscrapes/safety_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_telecom=pd.read_csv('./webscrapes/telecom_Smyrna_df.csv',index_col='Unnamed: 0')
symrna_transit=pd.read_csv('./webscrapes/trans_Smyrna_df.csv',index_col='Unnamed: 0')
symrna=pd.concat([symrna_energy,
symrna_food,
symrna_haz,
symrna_health,
symrna_police,
symrna_safety,
symrna_telecom,
symrna_transit])
symrna.head()
# Out:
#                                                 name  \
# 0           Masters Generator and Electrical Service
# 1                        Powers Electrical Solutions
# 2  TE Certified Electrical, Plumbing, Heating & C...
# 3                                           RaceTrac
# 4                                  Handy Electrician
#
#                                              address    phone_number  \
# 0                               ['Smyrna, GA 30080']  (678) 756-2041
# 1                               ['Smyrna, GA 30080']  (404) 645-6843
# 2       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 3             ['2550 Spring Rd', 'Smyrna, GA 30080']  (678) 309-1390
# 4  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...  (678) 873-5674
#
#    location_latitude  location_longitude  is_closed     city  zip_code  \
# 0          33.889300          -84.485170      False   Smyrna   30080.0
# 1          33.892162          -84.486290      False   Smyrna   30080.0
# ...

# %%
statesboro_energy=pd.read_csv('./webscrapes/energy_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_food=pd.read_csv('./webscrapes/food_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_haz=pd.read_csv('./webscrapes/haz_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_health=pd.read_csv('./webscrapes/health_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_police=pd.read_csv('./webscrapes/police_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_safety=pd.read_csv('./webscrapes/safety_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_telecom=pd.read_csv('./webscrapes/telecom_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro_transit=pd.read_csv('./webscrapes/trans_Statesboro_df.csv',index_col='Unnamed: 0')
statesboro=pd.concat([statesboro_energy,
statesboro_food,
statesboro_haz,
statesboro_health,
statesboro_police,
statesboro_safety,
statesboro_telecom,
statesboro_transit])
statesboro.head()
# Out:
#               name                                            address  \
# 0         Parker's     ['24151 Highway 80 E', 'Statesboro, GA 30458']
# 1  Murphy USA 6759     ['729 Northside Dr E', 'Statesboro, GA 30458']
# 2         Parker's       ['1899 Chandler Rd', 'Statesboro, GA 30458']
# 3         Parker's           ['12399 US 301', 'Statesboro, GA 30458']
# 4   Gate Petroleum  ['33 Statesboro Mall', 'Ste 2', 'Statesboro, G...
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 212-2088          32.432842          -81.754728      False
# 1  (912) 489-2161          32.435971          -81.758784      False
# 2  (912) 681-7007          32.413367          -81.781716      False
# 3  (912) 225-1993          32.416249          -81.800783      False
# 4  (912) 764-7965          32.441750          -81.782654      False
#
#          city  zip_code            category  \
# 0  Statesboro   30458.0        Gas Stations
# ...

# %%
stockbridge_energy=pd.read_csv('./webscrapes/energy_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_food=pd.read_csv('./webscrapes/food_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_haz=pd.read_csv('./webscrapes/haz_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_health=pd.read_csv('./webscrapes/health_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_police=pd.read_csv('./webscrapes/police_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_safety=pd.read_csv('./webscrapes/safety_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_telecom=pd.read_csv('./webscrapes/telecom_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge_transit=pd.read_csv('./webscrapes/trans_Stockbridge_df.csv',index_col='Unnamed: 0')
stockbridge=pd.concat([stockbridge_energy,
stockbridge_food,
stockbridge_haz,
stockbridge_health,
stockbridge_police,
stockbridge_safety,
stockbridge_telecom,
stockbridge_transit])
stockbridge.head()
# Out:
#                 name                                            address  \
# 0           QuikTrip  ['1614 Hudson Bridge Rd', 'Stockbridge, GA 302...
# 1           QuikTrip     ['5260 N Henry Blvd', 'Stockbridge, GA 30281']
# 2  Handy Electrician  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...
# 3         Murphy USA  ['1440 Hudson Bridge Rd', 'Stockbridge, GA 302...
# 4           QuikTrip        ['2881 Forest Pkwy', 'Ellenwood, GA 30294']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (770) 506-4014          33.503768          -84.239675      False
# 1  (770) 389-0238          33.547913          -84.251661      False
# 2  (678) 873-5674          33.745860          -84.358690      False
# 3  (678) 289-2077          33.505394          -84.234688      False
# 4  (404) 363-6012          33.610821          -84.298849      False
#
#           city zip_code            category  \
# 0  Stockbridge    30281  Convenience Stores
# ...

# %%
stone_mountain_energy=pd.read_csv('./webscrapes/energy_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_food=pd.read_csv('./webscrapes/food_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_haz=pd.read_csv('./webscrapes/haz_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_health=pd.read_csv('./webscrapes/health_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_police=pd.read_csv('./webscrapes/police_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_safety=pd.read_csv('./webscrapes/safety_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_telecom=pd.read_csv('./webscrapes/telecom_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain_transit=pd.read_csv('./webscrapes/trans_Stone_Mountain_df.csv',index_col='Unnamed: 0')
stone_mountain=pd.concat([stone_mountain_energy,
stone_mountain_food,
stone_mountain_haz,
stone_mountain_health,
stone_mountain_police,
stone_mountain_safety,
stone_mountain_telecom,
stone_mountain_transit])
stone_mountain.head()
# Out:
#                                                 name  \
# 0  TE Certified Electrical, Plumbing, Heating & C...
# 1                                  Handy Electrician
# 2                                   Cameron Electric
# 3                                   Beazley Electric
# 4                                JEFF ELECTRIC CORP.
#
#                                              address    phone_number  \
# 0       ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 1  ['881 Memorial Dr SE', 'Ste 308', 'Atlanta, GA...  (678) 873-5674
# 2        ['3104 Lake Ridge Ln', 'Atlanta, GA 30338']  (404) 891-6448
# 3      ['1165 Lullwater Rd NE', 'Atlanta, GA 30307']  (404) 281-4896
# 4  ['1270 Caroline St NE', 'Ste D104', 'Atlanta, ...  (404) 775-4891
#
#    location_latitude  location_longitude  is_closed     city  zip_code  \
# 0          34.018702          -84.328872      False  Roswell     30075
# 1          33.745860          -84.358690      False  Atlanta     30316
# ...

# %%
toccoa_energy=pd.read_csv('./webscrapes/energy_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_food=pd.read_csv('./webscrapes/food_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_haz=pd.read_csv('./webscrapes/haz_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_health=pd.read_csv('./webscrapes/health_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_police=pd.read_csv('./webscrapes/police_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_safety=pd.read_csv('./webscrapes/safety_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_telecom=pd.read_csv('./webscrapes/telecom_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa_transit=pd.read_csv('./webscrapes/trans_Toccoa_df.csv',index_col='Unnamed: 0')
toccoa=pd.concat([toccoa_energy,
toccoa_food,
toccoa_haz,
toccoa_health,
toccoa_police,
toccoa_safety,
toccoa_telecom])
toccoa.head()
# Out:
#                                 name  \
# 0                     Ready Electric
# 1              Stan's Service Center
# 2                            Chevron
# 3  JN Electrical Temperature Control
# 4                      Isom Electric
#
#                                            address    phone_number  \
# 0                          ['Cleveland, GA 30528']  (706) 969-9964
# 1         ['74 W Currahee St', 'Toccoa, GA 30577']  (706) 886-4227
# 2             ['1061 Hwy 106', 'Toccoa, GA 30577']  (706) 886-7687
# 3  ['2379 Adams Town Rd', 'Bowersville, GA 30516']  (706) 245-7429
# 4    ['121 Green Cherry Rd', 'Anderson, SC 29625']  (864) 226-2433
#
#    location_latitude  location_longitude  is_closed         city  zip_code  \
# 0          34.644857          -83.457237      False    Cleveland     30528
# 1          34.577795          -83.331140      False       Toccoa     30577
# 2          34.531745          -83.326894      False       Toccoa     30577
# ...

# %%
valdosta_energy=pd.read_csv('./webscrapes/energy_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_food=pd.read_csv('./webscrapes/food_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_haz=pd.read_csv('./webscrapes/haz_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_health=pd.read_csv('./webscrapes/health_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_police=pd.read_csv('./webscrapes/police_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_safety=pd.read_csv('./webscrapes/safety_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_telecom=pd.read_csv('./webscrapes/telecom_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta_transit=pd.read_csv('./webscrapes/trans_Valdosta_df.csv',index_col='Unnamed: 0')
valdosta=pd.concat([valdosta_energy,
valdosta_food,
valdosta_haz,
valdosta_health,
valdosta_police,
valdosta_safety,
valdosta_telecom,
valdosta_transit])
valdosta.head()
# Out:
#                   name                                           address  \
# 0  Pilot Travel Center        ['3460 Madison Hwy', 'Valdosta, GA 31601']
# 1  Pilot Travel Center        ['3495 Madison Hwy', 'Valdosta, GA 31601']
# 2                   Bp     ['2001 Boone Dairy Rd', 'Valdosta, GA 31601']
# 3              RaceWay  ['1406 N St Augustine Rd', 'Valdosta, GA 31602']
# 4             Sun stop         ['2112 W Hill Ave', 'Valdosta, GA 31601']
#
#      phone_number  location_latitude  location_longitude  is_closed      city  \
# 0  (229) 293-0388          30.754390          -83.273250      False  Valdosta
# 1  (229) 244-8034          30.753161          -83.272114      False  Valdosta
# 2             NaN          30.819161          -83.313526      False  Valdosta
# 3  (229) 249-8986          30.846821          -83.334763      False  Valdosta
# 4  (229) 474-6040          30.816883          -83.320692      False  Valdosta
#
#    zip_code            category  \
# ...

# %%
warner_robins_energy=pd.read_csv('./webscrapes/energy_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_food=pd.read_csv('./webscrapes/food_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_haz=pd.read_csv('./webscrapes/haz_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_health=pd.read_csv('./webscrapes/health_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_police=pd.read_csv('./webscrapes/police_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_safety=pd.read_csv('./webscrapes/safety_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_telecom=pd.read_csv('./webscrapes/telecom_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins_transit=pd.read_csv('./webscrapes/trans_Warner_Robins_df.csv',index_col='Unnamed: 0')
warner_robins=pd.concat([warner_robins_energy,
warner_robins_food,
warner_robins_haz,
warner_robins_health,
warner_robins_police,
warner_robins_safety,
warner_robins_telecom,
warner_robins_transit])
warner_robins.head()
# Out:
#                     name                                          address  \
# 0                 Kroger  ['3094 Watson Blvd', 'Warner Robins, GA 31093']
# 1     Kroger Gas Station  ['113 Russell Pkwy', 'Warner Robins, GA 31088']
# 2                  Lo Lo  ['701 N Houston Rd', 'Warner Robins, GA 31093']
# 3        Exxon Food Mart   ['1001 Elberta Rd', 'Warner Robins, GA 31093']
# 4  LOLO Cigarette Outlet                      ['Warner Robins, GA 31005']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (478) 971-2320          32.618997          -83.695371      False
# 1             NaN          32.593517          -83.625461      False
# 2  (478) 922-0601          32.626709          -83.641922      False
# 3  (478) 293-4270          32.635730          -83.634250      False
# 4             NaN          32.564250          -83.653050      False
#
#             city  zip_code       category  \
# 0  Warner Robins     31093        Grocery
# ...

# %%
woodstock_energy=pd.read_csv('./webscrapes/energy_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_food=pd.read_csv('./webscrapes/food_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_haz=pd.read_csv('./webscrapes/haz_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_health=pd.read_csv('./webscrapes/health_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_police=pd.read_csv('./webscrapes/police_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_safety=pd.read_csv('./webscrapes/safety_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_telecom=pd.read_csv('./webscrapes/telecom_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock_transit=pd.read_csv('./webscrapes/trans_Woodstock_df.csv',index_col='Unnamed: 0')
woodstock=pd.concat([woodstock_energy,
woodstock_food,
woodstock_haz,
woodstock_health,
woodstock_police,
woodstock_safety,
woodstock_telecom,
woodstock_transit])
woodstock.head()
# Out:
#                                                 name  \
# 0                                           QuikTrip
# 1  TE Certified Electrical, Plumbing, Heating & C...
# 2                             Lightning Bug Electric
# 3                                           QuikTrip
# 4                                           RaceTrac
#
#                                         address    phone_number  \
# 0        ['9765 Hwy 92', 'Woodstock, GA 30188']  (770) 591-4274
# 1  ['9800 Old Dogwood Rd', 'Roswell, GA 30075']  (770) 667-6937
# 2                        ['Marietta, GA 30066']  (404) 471-3847
# 3     ['4865 Old Hwy 5', 'Woodstock, GA 30188']  (678) 445-2753
# 4       ['155 Hames Rd', 'Woodstock, GA 30188']  (770) 926-4216
#
#    location_latitude  location_longitude  is_closed       city  zip_code  \
# 0          34.086919          -84.527236      False  Woodstock     30188
# 1          34.018702          -84.328872      False    Roswell     30075
# ...

# %%
hartwell_energy=pd.read_csv('./webscrapes/energy_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_food=pd.read_csv('./webscrapes/food_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_haz=pd.read_csv('./webscrapes/haz_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_health=pd.read_csv('./webscrapes/health_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_police=pd.read_csv('./webscrapes/police_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_safety=pd.read_csv('./webscrapes/safety_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_telecom=pd.read_csv('./webscrapes/telecom_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell_transit=pd.read_csv('./webscrapes/trans_Hartwell_df.csv',index_col='Unnamed: 0')
hartwell=pd.concat([hartwell_energy,
hartwell_food,
hartwell_haz,
hartwell_health,
hartwell_police,
hartwell_safety,
hartwell_telecom,
hartwell_transit])
hartwell.head()
# Out:
#                                         name  \
# 0                           Hartwell Chevron
# 1               Detter Plumbing and Electric
# 2  Dennis Holland Heating & Air & Electrical
# 3                  W.A.V.Electrical Services
# 4          JN Electrical Temperature Control
#
#                                            address    phone_number  \
# 0      ['200 E Franklin St', 'Hartwell, GA 30643']  (706) 376-2823
# 1           ['168 Short Dr', 'Hartwell, GA 30643']  (706) 376-2674
# 2    ['1288 Hodges Mill Rd', 'Hartwell, GA 30643']  (706) 376-3713
# 3             ['310 Brady Dr', 'Seneca, SC 29678']  (864) 814-8054
# 4  ['2379 Adams Town Rd', 'Bowersville, GA 30516']  (706) 245-7429
#
#    location_latitude  location_longitude  is_closed         city  zip_code  \
# 0          34.353090          -82.924115      False     Hartwell     30643
# 1          34.306750          -82.995610      False     Hartwell     30643
# ...

# %%
thomasville_energy=pd.read_csv('./webscrapes/energy_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville_food=pd.read_csv('./webscrapes/food_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville_health=pd.read_csv('./webscrapes/health_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville_police=pd.read_csv('./webscrapes/police_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville_safety=pd.read_csv('./webscrapes/safety_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville_telecom=pd.read_csv('./webscrapes/telecom_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville_transit=pd.read_csv('./webscrapes/trans_Thomasville_df.csv',index_col='Unnamed: 0')
thomasville=pd.concat([thomasville_energy,
thomasville_food,
thomasville_health,
thomasville_police,
thomasville_safety,
thomasville_telecom,
thomasville_transit])
thomasville.head()
# Out:
#                            name  \
# 0           Pilot Travel Center
# 1            Plantation Propane
# 2               Quality L P Gas
# 3  Albritton Electrical Service
# 4                   Electrotech
#
#                                              address    phone_number  \
# 0               ['1701 Hwy 84 E', 'Hayti, MO 63851']  (573) 359-2007
# 1         ['403 Smith Ave', 'Thomasville, GA 31792']  (229) 228-4427
# 2               ['293 Joyner Rd', 'Cairo, GA 39828']  (229) 377-7442
# 3      ['4821 Six Oaks Dr', 'Tallahassee, FL 32303']  (850) 562-1193
# 4  ['3436 Briar Branch Trl', 'Tallahassee, FL 323...  (850) 668-9291
#
#    location_latitude  location_longitude  is_closed         city  zip_code  \
# 0          36.227769          -89.725121      False        Hayti     63851
# 1          30.835920          -83.974190      False  Thomasville     31792
# 2          30.862337          -84.187748      False        Cairo     39828
# ...

# %%
thomson_energy=pd.read_csv('./webscrapes/energy_Thomson_df.csv',index_col='Unnamed: 0')
thomson_food=pd.read_csv('./webscrapes/food_Thomson_df.csv',index_col='Unnamed: 0')
thomson_health=pd.read_csv('./webscrapes/health_Thomson_df.csv',index_col='Unnamed: 0')
thomson_police=pd.read_csv('./webscrapes/police_Thomson_df.csv',index_col='Unnamed: 0')
thomson_safety=pd.read_csv('./webscrapes/safety_Thomson_df.csv',index_col='Unnamed: 0')
thomson_telecom=pd.read_csv('./webscrapes/telecom_Thomson_df.csv',index_col='Unnamed: 0')
thomson_transit=pd.read_csv('./webscrapes/trans_Thomson_df.csv',index_col='Unnamed: 0')
thomson=pd.concat([thomson_energy,
thomson_food,
thomson_health,
thomson_police,
thomson_safety,
thomson_telecom,
thomson_transit])
thomson.head()
# Out:
#                       name                                         address  \
# 0       Love's Travel Stop  ['2129 Washington Rd NW', 'Thomson, GA 30824']
# 1  Raceway Service Station     ['1920 Washington Rd', 'Thomson, GA 30824']
# 2                 Circle K     ['1786 Washington Rd', 'Thomson, GA 30824']
# 3       Minyard's Electric            ['254 Rose St', 'Augusta, GA 30907']
# 4                    Shell      ['440 Lewiston Rd', 'Grovetown, GA 30813']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (706) 843-9833          33.514180          -82.503595      False
# 1  (706) 595-5030          33.508461          -82.502068      False
# 2  (706) 595-9840          33.504823          -82.502389      False
# 3  (706) 863-3242          33.506830          -82.087570      False
# 4  (706) 650-1178          33.487400          -82.199324      False
#
#         city  zip_code            category  \
# 0    Thomson     30824  Convenience Stores
# ...

# %%
rossville_energy=pd.read_csv('./webscrapes/energy_Rossville_df.csv',index_col='Unnamed: 0')
rossville_food=pd.read_csv('./webscrapes/food_Rossville_df.csv',index_col='Unnamed: 0')
rossville_health=pd.read_csv('./webscrapes/health_Rossville_df.csv',index_col='Unnamed: 0')
rossville_police=pd.read_csv('./webscrapes/police_Rossville_df.csv',index_col='Unnamed: 0')
rossville_safety=pd.read_csv('./webscrapes/safety_Rossville_df.csv',index_col='Unnamed: 0')
rossville_telecom=pd.read_csv('./webscrapes/telecom_Rossville_df.csv',index_col='Unnamed: 0')
rossville_transit=pd.read_csv('./webscrapes/trans_Rossville_df.csv',index_col='Unnamed: 0')
rossville=pd.concat([rossville_energy,
rossville_food,
rossville_health,
rossville_police,
rossville_safety,
rossville_telecom,
rossville_transit])
rossville.head()
# Out:
#                name                                        address  \
# 0   Foster Electric    ['2626 Walker Rd', 'Chattanooga, TN 37421']
# 1      Speedway Gas  ['4222 Ringgold Rd', 'Chattanooga, TN 37412']
# 2             MAPCO  ['2055 McFarland Ave', 'Rossville, GA 30741']
# 3  Handymen On-Call   ['111 Chestnut St', 'Chattanooga, TN 37402']
# 4        MAPCO Mart       ['2618 Hwy 193', 'Flintstone, GA 30725']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (423) 892-6759          35.054270          -85.133500      False
# 1  (423) 892-5211          34.996196          -85.241095      False
# 2  (706) 861-2382          34.945530          -85.284810      False
# 3  (423) 240-4227          35.056066          -85.311976      False
# 4  (706) 820-9153          34.948250          -85.335970      False
#
#           city  zip_code      category  \
# 0  Chattanooga     37421  Electricians
# 1  Chattanooga     37412  Gas Stations
# ...

# %%
lyons_energy=pd.read_csv('./webscrapes/energy_Lyons_df.csv',index_col='Unnamed: 0')
lyons_food=pd.read_csv('./webscrapes/food_Lyons_df.csv',index_col='Unnamed: 0')
lyons_health=pd.read_csv('./webscrapes/health_Lyons_df.csv',index_col='Unnamed: 0')
lyons_police=pd.read_csv('./webscrapes/police_Lyons_df.csv',index_col='Unnamed: 0')
lyons_safety=pd.read_csv('./webscrapes/safety_Lyons_df.csv',index_col='Unnamed: 0')
lyons_telecom=pd.read_csv('./webscrapes/telecom_Lyons_df.csv',index_col='Unnamed: 0')
lyons_transit=pd.read_csv('./webscrapes/trans_Lyons_df.csv',index_col='Unnamed: 0')
lyons=pd.concat([lyons_energy,
lyons_food,
lyons_health,
lyons_police,
lyons_safety,
lyons_telecom,
lyons_transit])
lyons.head()
# Out:
#                       name                                     address  \
# 0  Big Al's Country Market  ['1210 Highway 29', 'Tarrytown, GA 30470']
# 1                   Enmark    ['1401 E First St', 'Vidalia, GA 30474']
# 2             Marathon Gas  ['3129 US Hwy 1 S', 'Twin City, GA 30471']
# 3                 Parker's     ['1118 S Lewis St', 'Metter, GA 30439']
# 4                 Johns #2         ['4384 GA-15', 'Vidalia, GA 30474']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 538-8900          32.203186          -82.413838      False
# 1  (912) 537-1371          32.211147          -82.396454      False
# 2  (912) 562-4230          32.403450          -82.305126      False
# 3  (912) 623-4463          32.378934          -82.062815      False
# 4             NaN          32.128612          -82.396990      False
#
#         city  zip_code            category  \
# 0  Tarrytown     30470  Convenience Stores
# ...

# %%
sylvania_energy=pd.read_csv('./webscrapes/energy_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania_food=pd.read_csv('./webscrapes/food_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania_health=pd.read_csv('./webscrapes/health_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania_police=pd.read_csv('./webscrapes/police_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania_safety=pd.read_csv('./webscrapes/safety_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania_telecom=pd.read_csv('./webscrapes/telecom_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania_transit=pd.read_csv('./webscrapes/trans_Sylvania_df.csv',index_col='Unnamed: 0')
sylvania=pd.concat([sylvania_energy,
sylvania_food,
sylvania_health,
sylvania_police,
sylvania_safety,
sylvania_telecom,
sylvania_transit])
sylvania.head()
# Out:
#                name                                            address  \
# 0          Parker's     ['24151 Highway 80 E', 'Statesboro, GA 30458']
# 1  J & T Minit Mart             ['4636 US Hwy 25', 'Portal, GA 30450']
# 2   Murphy USA 6759     ['729 Northside Dr E', 'Statesboro, GA 30458']
# 3        Zip-N-Food  ['7462 Stilson Leefield Rd', 'Brooklet, GA 304...
# 4          Parker's           ['222 Drayton St', 'Savannah, GA 31401']
#
#      phone_number  location_latitude  location_longitude  is_closed  \
# 0  (912) 212-2088          32.432842          -81.754728      False
# 1  (912) 865-2000          32.579727          -81.888418      False
# 2  (912) 489-2161          32.435971          -81.758784      False
# 3  (912) 842-4222          32.418967          -81.612910      False
# 4  (912) 233-1000          32.075650          -81.091696      False
#
#          city  zip_code            category  \
# 0  Statesboro   30458.0        Gas Stations
# ...

# %%
waynesboro_energy=pd.read_csv('./webscrapes/energy_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro_food=pd.read_csv('./webscrapes/food_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro_health=pd.read_csv('./webscrapes/health_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro_police=pd.read_csv('./webscrapes/police_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro_safety=pd.read_csv('./webscrapes/safety_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro_telecom=pd.read_csv('./webscrapes/telecom_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro_transit=pd.read_csv('./webscrapes/trans_Waynesboro_df.csv',index_col='Unnamed: 0')
waynesboro=pd.concat([waynesboro_energy,
waynesboro_food,
waynesboro_health,
waynesboro_police,
waynesboro_safety,
waynesboro_telecom,
waynesboro_transit])
waynesboro.head()
# Out:
#                         name  \
# 0    Mr. Electric of Augusta
# 1  Fort Gordon Post Exchange
# 2  Pennington Power Products
# 3       1st Call Maintenance
# 4           Gate 1 Shoppette
#
#                                              address    phone_number  \
# 0                              ['Augusta, GA 30906']  (706) 619-2525
# 1  ['49300 Ave Of The States', 'Hephzibah, GA 308...  (706) 793-1160
# 2            ['1814 Lumkin Rd', 'Augusta, GA 30906']  (706) 793-4992
# 3                              ['Augusta, GA 30909']  (706) 836-2665
# 4       ['100 Chamberlain Ave', 'Augusta, GA 30905']  (706) 792-9707
#
#    location_latitude  location_longitude  is_closed       city  zip_code  \
# 0          33.389598          -81.980793      False    Augusta     30906
# 1          33.394290          -82.117450      False  Hephzibah     30815
# 2          33.416450          -82.008930      False    Augusta     30906
# 3          33.468840          -82.062000      False    Augusta     30909
# ...

# %% [markdown]
# Create and do cleaning for full dataframe

# %%
city_info=pd.concat([albany,alpharetta,athens,atlanta,augusta,brookhaven,carrollton,college_park,columbus,
conyers,cumming,dalton,douglasville,duluth,dunwoody,east_point,gainesville,griffin,hinesville,johns_creek,
kennesaw,lagrange,macon,marietta,milton,newnan,peachtree_city,peachtree_corner,rome,roswell,sandy_springs,
savannah,symrna,stockbridge,stone_mountain,valdosta,warner_robins,woodstock,adel,americus,auburn,statesboro
,toccoa,baxley,milledgeville,saint_simons_island,cedartown,clarkesville, jasper,folkston,cochran,commerce
,eastman,guyton,hartwell,thomasville,thomson,rossville,lyons,waynesboro,sylvania],ignore_index=True)

# %%
city_info.head()
# Out:
#                                         name  \
# 0                                     Enmark
# 1  B & B Electrical Contractors & Associates
# 2             Preferred Home Repair Handyman
# 3                              Homerun Foods
# 4                        Pilot Travel Center
#
#                                     address    phone_number  \
# 0    ['2424 Clark Ave', 'Albany, GA 31705']  (229) 483-0137
# 1  ['1008 W Broad Ave', 'Albany, GA 31701']  (229) 435-0287
# 2  ['2823 Meredyth Dr', 'Albany, GA 31707']  (229) 317-2271
# 3    ['2722 Dawson Rd', 'Albany, GA 31707']  (229) 435-0443
# 4    ['310 Cordele Rd', 'Albany, GA 31705']  (229) 878-1355
#
#    location_latitude  location_longitude  is_closed    city zip_code  \
# 0          31.579650          -84.091130      False  Albany    31705
# 1          31.576410          -84.174530      False  Albany    31701
# 2          31.611086          -84.221721      False  Albany    31707
# ...

# %%
city_info.shape
# Out:
# (316821, 10)

# %% [markdown]
# Create the FEMA categories into true fema indicated code.

# %%
city_info['FEMA_category']=city_info['FEMA_category'].map(FEMA_dict)

# %%
city_info.tail()
# Out:
#                            name                                       address  \
# 316816               SC Express    ['2818 Columbia Hwy N', 'Aiken, SC 29805']
# 316817  Summerville Cab Company  ['104 Sundance Ct', 'Summerville, SC 29486']
# 316818               SC Express    ['2818 Columbia Hwy N', 'Aiken, SC 29805']
# 316819  Summerville Cab Company  ['104 Sundance Ct', 'Summerville, SC 29486']
# 316820  Summerville Cab Company  ['104 Sundance Ct', 'Summerville, SC 29486']
#
#           phone_number  location_latitude  location_longitude  is_closed  \
# 316816  (803) 648-9977           33.67382           -81.67077      False
# 316817  (843) 518-0058           33.03142           -80.13244      False
# 316818  (803) 648-9977           33.67382           -81.67077      False
# 316819  (843) 518-0058           33.03142           -80.13244      False
# 316820  (843) 518-0058           33.03142           -80.13244      False
#
#                city zip_code category       FEMA_category
# ...

# %% [markdown]
# Drop duplicates to ensure all data is best represented.

# %%
city_info.drop_duplicates(keep='first',inplace=True)

# %%
city_info.shape
# Out:
# (9101, 10)

# %%
city_info.isna().sum()
# Out:
# name                    0
# address                 0
# phone_number          238
# location_latitude       2
# location_longitude      2
# is_closed               0
# city                    0
# zip_code               26
# category                0
# FEMA_category           0
# dtype: int64

# %%
city_info=city_info[city_info['zip_code'].isna()==False]

# %%
city_info.fillna("None",inplace=True)

# %%
city_info.isna().sum()
# Out:
# name                  0
# address               0
# phone_number          0
# location_latitude     0
# location_longitude    0
# is_closed             0
# city                  0
# zip_code              0
# category              0
# FEMA_category         0
# dtype: int64

# %%
city_info.head()
# Out:
#                                         name  \
# 0                                     Enmark
# 1  B & B Electrical Contractors & Associates
# 2             Preferred Home Repair Handyman
# 3                              Homerun Foods
# 4                        Pilot Travel Center
#
#                                     address    phone_number  \
# 0    ['2424 Clark Ave', 'Albany, GA 31705']  (229) 483-0137
# 1  ['1008 W Broad Ave', 'Albany, GA 31701']  (229) 435-0287
# 2  ['2823 Meredyth Dr', 'Albany, GA 31707']  (229) 317-2271
# 3    ['2722 Dawson Rd', 'Albany, GA 31707']  (229) 435-0443
# 4    ['310 Cordele Rd', 'Albany, GA 31705']  (229) 878-1355
#
#    location_latitude  location_longitude  is_closed    city zip_code  \
# 0          31.579650          -84.091130      False  Albany    31705
# 1          31.576410          -84.174530      False  Albany    31701
# 2          31.611086          -84.221721      False  Albany    31707
# ...

# %%
city_info=city_info[city_info['address'].str.contains('GA')]

# %%
city_info.shape
# Out:
# (8581, 10)

# %%
city_info.reset_index(drop='index',inplace=True)

# %%
city_info.tail()
# Out:
#                                      name  \
# 8576                      4 and 20 Bakers
# 8577            Effingham Family Medicine
# 8578                Kids First Pediatrics
# 8579  St. Joseph's/Candler Immediate Care
# 8580                              Verizon
#
#                                                 address    phone_number  \
# 8576           ['115 N Ennis St', 'Sylvania, GA 30467']  (912) 451-4200
# 8577              ['100 Goshen Rd', 'Rincon, GA 31326']  (912) 826-6000
# 8578  ['808 Towne Park Dr W', 'Ste 200', 'Rincon, GA...  (912) 826-0273
# 8579       ['5621 Ga Highway 21 S', 'Rincon, GA 31326']  (912) 295-5860
# 8580        ['5442 S Columbia Ave', 'Rincon, GA 31326']  (912) 826-4413
#
#       location_latitude  location_longitude  is_closed      city zip_code  \
# 8576          32.750739          -81.638720      False  Sylvania    30467
# 8577          32.251648          -81.212265      False    Rincon    31326
# ...

# %%
list(set(city_info['city'].sort_values()))[:3]
# Out:
# ['St Simons Island', 'Ft Oglethorpe', 'Pinehurst']

# %%
city_info.loc[city_info['city']=='ALPHARETTA','city']='Alpharetta'
city_info.loc[city_info['city']=='AUGUSTA','city']='Augusta'
city_info.loc[city_info['city']=='LILBURN','city']='Liliburn'
city_info.loc[city_info['city']=='WARNER ROBINS','city']='Warner Robins'
city_info.loc[city_info['city']=='augusta','city']='Augusta'
city_info.loc[city_info['city']=='Augusta ','city']='Augusta'
city_info.loc[city_info['city']=='Grovetown,','city']='Grovetown'
city_info.loc[city_info['city']=='watkinsville','city']='Watkinsville'
city_info.loc[city_info['city']=='Liliburn','city']='Lilburn'
city_info.loc[city_info['city']=='Mcdonough','city']='McDonough'
city_info.loc[city_info['city']=='Nocross','city']='Norcross'
city_info.loc[city_info['city']=='DALTON','city']='Dalton'
city_info.loc[city_info['city']=='Moody A F B','city']='Moody AFB'
city_info.loc[city_info['city']=='Albany ','city']='Albany'
city_info.loc[city_info['city']=='Columbus ','city']='Columbus'
city_info.loc[city_info['city']=='Peahtree City','city']='Peachtree City'
city_info.loc[city_info['city']=='Peachtree Cty','city']='Peachtree City'
city_info.loc[city_info['city']=='Savannah ','city']='Savannah'
city_info.loc[city_info['city']=='Chatt Hills','city']='Chattahoochee Hills'
city_info.loc[city_info['city']=='Powder Spring','city']='Powder Springs'
city_info.loc[city_info['city']=='Mc Donough','city']='McDonough'
city_info.loc[city_info['city']=='La Grange','city']='LaGrange'
city_info.loc[city_info['city']=='Lagrange','city']='LaGrange'
city_info.loc[city_info['city']=='hiram','city']='Hiram'
city_info.loc[city_info['city']=='kennesaw','city']='Kennesaw'
city_info.loc[city_info['city']=='woodstock','city']='Woodstock'
city_info.loc[city_info['name']=='Any Lab Test Now Kennesaw','city']='Kennesaw'
city_info.loc[city_info['name']=='Any Lab Test Now Jonesboro','city']='Jonesboro'
city_info.loc[city_info['city']=='St Marys','city']='Saint Marys'
city_info.loc[city_info['city']=='St. Marys','city']='Saint Marys'
city_info.loc[city_info['city']=='St Simons','city']='Saint Simons Island'
city_info.loc[city_info['city']=='St Simons Island','city']='Saint Simons Island'
city_info.loc[city_info['city']=='St. Simons','city']='Saint Simons Island'
city_info.loc[city_info['city']=='St. Simons Island','city']='Saint Simons Island' 
city_info.loc[city_info['city']=='NORCROSS','city']='Norcross'
city_info.loc[city_info['name']=='Sapience Cloud','city']='Stockbridge'
city_info.loc[city_info['city']=='Ft Oglethorpe','city']='Fort Oglethorpe'
city_info.loc[city_info['city']=='Bethelhem','city']='Bethlehem'
city_info.loc[city_info['city']=='Fulton','city']='Atlanta'

# %%
list((set(city_info['city'].sort_values())))[-5:]
# Out:
# ['Plainville', 'Cordele', 'McRae', 'Chamblee', 'Eastman']

# %%
population=pd.read_csv('./Clean Data/2010+Census+Population+By+Zipcode+(ZCTA).csv')

# %%
population.head()
# Out:
#    Zip Code ZCTA  2010 Census Population
# 0           1001                   16769
# 1           1002                   29049
# 2           1003                   10372
# 3           1005                    5079
# 4           1007                   14649

# %%
zip_centers=pd.read_csv('./Clean Data/us-zip-code-latitude-and-longitude.csv',sep=';')

# %%
zip_centers.head()
# Out:
#      Zip      City State   Latitude  Longitude  Timezone  \
# 0  71937      Cove    AR  34.398483  -94.39398        -6
# 1  72044  Edgemont    AR  35.624351  -92.16056        -6
# 2  56171  Sherburn    MN  43.660847  -94.74357        -6
# 3  49430    Lamont    MI  43.010337  -85.89754        -5
# 4  52585  Richland    IA  41.194129  -91.98027        -6
#
#    Daylight savings time flag             geopoint
# 0                           1  34.398483,-94.39398
# 1                           1  35.624351,-92.16056
# 2                           1  43.660847,-94.74357
# 3                           1  43.010337,-85.89754
# 4                           1  41.194129,-91.98027

# %%
zip_centers.drop(columns=['Timezone','Daylight savings time flag','geopoint'],inplace=True)

# %%
zip_centers=zip_centers[zip_centers['State'].str.contains('GA')]

# %%
zip_centers.reset_index(drop=True,inplace=True)
zip_centers.head()
# Out:
#      Zip          City State   Latitude  Longitude
# 0  31150       Atlanta    GA  33.844371 -84.474050
# 1  31646  Saint George    GA  30.518903 -82.080630
# 2  31826        Shiloh    GA  32.803518 -84.693840
# 3  30334       Atlanta    GA  33.702657 -84.439127
# 4  31606      Valdosta    GA  30.802411 -83.196240

# %%
zip_info=zip_centers.merge(population, left_on='Zip',right_on='Zip Code ZCTA')
zip_info.head()
# Out:
#      Zip          City State   Latitude  Longitude  Zip Code ZCTA  \
# 0  31826        Shiloh    GA  32.803518 -84.693840          31826
# 1  30334       Atlanta    GA  33.702657 -84.439127          30334
# 2  31606      Valdosta    GA  30.802411 -83.196240          31606
# 3  30531      Cornelia    GA  34.514215 -83.541180          30531
# 4  30746  Sugar Valley    GA  34.574804 -85.024820          30746
#
#    2010 Census Population
# 0                    2350
# 1                       1
# 2                    3861
# 3                   11279
# 4                    1223

# %%
zip_info.drop(columns='Zip Code ZCTA',inplace=True)
zip_info.head()
# Out:
#      Zip          City State   Latitude  Longitude  2010 Census Population
# 0  31826        Shiloh    GA  32.803518 -84.693840                    2350
# 1  30334       Atlanta    GA  33.702657 -84.439127                       1
# 2  31606      Valdosta    GA  30.802411 -83.196240                    3861
# 3  30531      Cornelia    GA  34.514215 -83.541180                   11279
# 4  30746  Sugar Valley    GA  34.574804 -85.024820                    1223

# %%
city_pop = zip_info.groupby('City').sum()[['2010 Census Population']]
city_pop.to_csv('./Clean Data/city_pop.csv')

# %%
fema_info=city_info.merge(zip_info, how='right',left_on='zip_code',right_on='Zip')
fema_info.head()
# Out:
#                        name                                   address  \
# 0                    Enmark    ['2424 Clark Ave', 'Albany, GA 31705']
# 1       Pilot Travel Center    ['310 Cordele Rd', 'Albany, GA 31705']
# 2  JC's Wingz & Concessions  ['2221 E Broad Ave', 'Albany, GA 31705']
# 3                    Enmark    ['2424 Clark Ave', 'Albany, GA 31705']
# 4       Pilot Travel Center    ['310 Cordele Rd', 'Albany, GA 31705']
#
#      phone_number  location_latitude  location_longitude is_closed    city  \
# 0  (229) 483-0137          31.579650          -84.091130     False  Albany
# 1  (229) 878-1355          31.580555          -84.086110     False  Albany
# 2  (229) 496-2290          31.574913          -84.096738     False  Albany
# 3  (229) 483-0137          31.579650          -84.091130     False  Albany
# 4  (229) 878-1355          31.580555          -84.086110     False  Albany
#
#   zip_code            category                FEMA_category    Zip    City  \
# ...

# %%
fema_info.shape
# Out:
# (8652, 16)

# %%
fema_info.isna().sum()
# Out:
# name                      294
# address                   294
# phone_number              294
# location_latitude         294
# location_longitude        294
# is_closed                 294
# city                      294
# zip_code                  294
# category                  294
# FEMA_category             294
# Zip                         0
# City                        0
# State                       0
# Latitude                    0
# Longitude                   0
# 2010 Census Population      0
# dtype: int64

# %%
fema_info['city']=fema_info['City']
fema_info['zip_code']=fema_info['Zip']
fema_info.isna().sum()
# Out:
# name                      294
# address                   294
# phone_number              294
# location_latitude         294
# location_longitude        294
# is_closed                 294
# city                        0
# zip_code                    0
# category                  294
# FEMA_category             294
# Zip                         0
# City                        0
# State                       0
# Latitude                    0
# Longitude                   0
# 2010 Census Population      0
# dtype: int64

# %%
fema_info.drop(columns=['Zip','City','State'],inplace=True)
fema_info.rename(columns={'Latitude':'zip_code_latitude',
                          'Longitude':'zip_code_longitude',
                          '2010 Census Population':'2010_zip_code_census_population'},inplace=True)
fema_info.tail()
# Out:
#      name address phone_number  location_latitude  location_longitude  \
# 8647  NaN     NaN          NaN                NaN                 NaN
# 8648  NaN     NaN          NaN                NaN                 NaN
# 8649  NaN     NaN          NaN                NaN                 NaN
# 8650  NaN     NaN          NaN                NaN                 NaN
# 8651  NaN     NaN          NaN                NaN                 NaN
#
#      is_closed       city  zip_code category FEMA_category  zip_code_latitude  \
# 8647       NaN   Wildwood     30757      NaN           NaN          34.954188
# 8648       NaN       Clyo     31303      NaN           NaN          32.508239
# 8649       NaN    Camilla     31730      NaN           NaN          31.209854
# 8650       NaN   Montrose     31065      NaN           NaN          32.564036
# 8651       NaN  Sale City     31784      NaN           NaN          31.258794
#
#       zip_code_longitude  2010_zip_code_census_population
# ...

# %%
fema_info['name'].replace(np.nan,'None',inplace=True)
fema_info['address'].replace(np.nan,'None',inplace=True)
fema_info['phone_number'].replace(np.nan,'None',inplace=True)
fema_info['category'].replace(np.nan,'None',inplace=True)
fema_info['FEMA_category'].replace(np.nan,'None',inplace=True)
fema_info['location_latitude'].replace(np.nan,0,inplace=True)
fema_info['location_longitude'].replace(np.nan,0,inplace=True)
fema_info['is_closed'].replace(np.nan,False,inplace=True)

# %%
fema_info.shape
# Out:
# (8652, 13)

# %%
fema_info.tail()
# Out:
#       name address phone_number  location_latitude  location_longitude  \
# 8647  None    None         None                0.0                 0.0
# 8648  None    None         None                0.0                 0.0
# 8649  None    None         None                0.0                 0.0
# 8650  None    None         None                0.0                 0.0
# 8651  None    None         None                0.0                 0.0
#
#       is_closed       city  zip_code category FEMA_category  \
# 8647      False   Wildwood     30757     None          None
# 8648      False       Clyo     31303     None          None
# 8649      False    Camilla     31730     None          None
# 8650      False   Montrose     31065     None          None
# 8651      False  Sale City     31784     None          None
#
#       zip_code_latitude  zip_code_longitude  2010_zip_code_census_population
# 8647          34.954188           -85.43232                             1787
# ...

# %%
fema_info.head()
# Out:
#                        name                                   address  \
# 0                    Enmark    ['2424 Clark Ave', 'Albany, GA 31705']
# 1       Pilot Travel Center    ['310 Cordele Rd', 'Albany, GA 31705']
# 2  JC's Wingz & Concessions  ['2221 E Broad Ave', 'Albany, GA 31705']
# 3                    Enmark    ['2424 Clark Ave', 'Albany, GA 31705']
# 4       Pilot Travel Center    ['310 Cordele Rd', 'Albany, GA 31705']
#
#      phone_number  location_latitude  location_longitude  is_closed    city  \
# 0  (229) 483-0137          31.579650          -84.091130      False  Albany
# 1  (229) 878-1355          31.580555          -84.086110      False  Albany
# 2  (229) 496-2290          31.574913          -84.096738      False  Albany
# 3  (229) 483-0137          31.579650          -84.091130      False  Albany
# 4  (229) 878-1355          31.580555          -84.086110      False  Albany
#
#    zip_code            category                FEMA_category  \
# ...

# %%
fema_info.dtypes
# Out:
# name                                object
# address                             object
# phone_number                        object
# location_latitude                  float64
# location_longitude                 float64
# is_closed                             bool
# city                                object
# zip_code                             int64
# category                            object
# FEMA_category                       object
# zip_code_latitude                  float64
# zip_code_longitude                 float64
# 2010_zip_code_census_population      int64
# dtype: object

# %%
fema_info['zip_code_longitude'] = fema_info['zip_code_longitude'].round(5)

# %%
fema_info.to_csv("./Clean Data/atl_fema_codes.csv")
